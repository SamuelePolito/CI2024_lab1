# %% [markdown]
# Copyright **`(c)`** 2024 Giovanni Squillero `<giovanni.squillero@polito.it>`
# [`https://github.com/squillero/computational-intelligence`](https://github.com/squillero/computational-intelligence)
# Free for personal or classroom use; see [`LICENSE.md`](https://github.com/squillero/computational-intelligence/blob/master/LICENSE.md) for details.

# %% [markdown]
# # Set Cover problem
#
# See: https://en.wikipedia.org/wiki/Set_cover_problem

# %%
from random import random, seed
from itertools import product
import numpy as np

from icecream import ic

# %% [markdown]
# ## Reproducible Initialization
#
# If you want to get reproducible results, use `rng` (and restart the kernel); for non-reproducible ones, use `np.random`.

# %%
UNIVERSE_SIZE = 10_000
NUM_SETS = 1_000
DENSITY = 0.2

rng = np.random.Generator(np.random.PCG64([UNIVERSE_SIZE, NUM_SETS, int(10_000 * DENSITY)]))

# %%
# DON'T EDIT THESE LINES!

SETS = np.random.random((NUM_SETS, UNIVERSE_SIZE)) < DENSITY
for s in range(UNIVERSE_SIZE):
    if not np.any(SETS[:, s]):
        SETS[np.random.randint(NUM_SETS), s] = True
COSTS = np.pow(SETS.sum(axis=1), 1.1)

# %% [markdown]
# ## Helper Functions

# %%
def valid(solution):
    """Checks wether solution is valid (ie. covers all universe)"""
    return np.all(np.logical_or.reduce(SETS[solution]))


def cost(solution):
    """Returns the cost of a solution (to be minimized)"""
    return COSTS[solution].sum()

# %% [markdown]
# ## Have Fun!

# %%
# A dumb solution of "all" sets
solution = np.full(NUM_SETS, True)
valid(solution), cost(solution)
# Out:
# (np.True_, np.float64(4281033.193893639))

# %%
# A random solution with random 50% of the sets
solution = rng.random(NUM_SETS) < .5
valid(solution), cost(solution)
# Out:
# (np.True_, np.float64(2140413.4999994165))

# %% [markdown]
# **Greedy algorithm**

# %%
def greedy_set_cover():
    solution = np.full(NUM_SETS, False)  # Start with no sets selected
    uncovered_elements = np.where(np.any(SETS, axis=0))[0]  # Elements still uncovered
    iteration = 0

    while not valid(solution):
        best_set_index = None
        max_uncovered = 0
        best_set_cost = cost(np.full(NUM_SETS, True))

        # Look for the best set to add
        for set_index in range(NUM_SETS):
            if not solution[set_index]:
                uncovered_in_set = np.sum(SETS[set_index] & ~np.logical_or.reduce(SETS[solution]))
                if uncovered_in_set > max_uncovered or (uncovered_in_set == max_uncovered and COSTS[set_index] < best_set_cost):
                    max_uncovered = uncovered_in_set
                    best_set_index = set_index
                    best_set_cost = COSTS[set_index]

        # Add the best set to the solution
        if best_set_index is not None:
            solution[best_set_index] = True
            uncovered_elements = np.setdiff1d(uncovered_elements, np.where(SETS[best_set_index])[0])


        ic(iteration, valid(solution), cost(solution), len(np.where(solution)[0]))
        iteration += 1

    return solution, cost(solution)

# Run the greedy algorithm
greedy_solution, greedy_cost = greedy_set_cover()
print(f"Greedy solution cost: {greedy_cost}")
# Out:
# ic| iteration: 0
#     valid(solution): np.False_
#     cost(solution): np.float64(4586.081777779552)
#     len(np.where(solution)[0]): 1
# ic| iteration: 1
#     valid(solution): np.False_
#     cost(solution): np.float64(9155.595266441425)
#     len(np.where(solution)[0]): 2
# ic| iteration: 2
#     valid(solution): np.False_
#     cost(solution): np.float64(13665.980975003891)
#     len(np.where(solution)[0]): 3
# ic| iteration: 3
#     valid(solution): np.False_
#     cost(solution): np.float64(18088.986960062353)
#     len(np.where(solution)[0]): 4
# ic| iteration: 4
#     valid(solution): np.False_
#     cost(solution): np.float64(22587.55553444305)
#     len(np.where(solution)[0]): 5
# ic| iteration: 5
#     valid(solution): np.False_
#     cost(solution): np.float64(27048.328268773814)
#     len(np.where(solution)[0]): 6
# ic| iteration: 6
#     valid(solution): np.False_
#     cost(solution): np.float64(31351.149250104198)
#     len(np.where(solution)[0]): 7
# ic| iteration: 7
#     valid(solution): np.False_
#     cost(solution): np.float64(35717.56010152493)
#     len(np.where(solution)[0]): 8
# ic| iteration: 8
#     valid(solution): np.False_
#     cost(solution): np.float64(40003.90870633204)
#     len(np.where(solution)[0]): 9
# ic| iteration: 9
#     valid(solution): np.False_
#     cost(solution): np.float64(44276.14270935905)
#     len(np.where(solution)[0]): 10
# ic| iteration: 10
#     valid(solution): np.False_
#     cost(solution): np.float64(48741.638336926495)
#     len(np.where(solution)[0]): 11
# ic| iteration: 11
#     valid(solution): np.False_
#     cost(solution): np.float64(53108.04918834723)
#     len(np.where(solution)[0]): 12
# ic| iteration: 12
#     valid(solution): np.False_
#     cost(solution): np.float64(57406.16319041501)
#     len(np.where(solution)[0]): 13
# ic| iteration: 13
#     valid(solution): np.False_
#     cost(solution): np.float64(61708.9841717454)
#     len(np.where(solution)[0]): 14
# ic| iteration: 14
#     valid(solution): np.False_
#     cost(solution): np.float64(66136.70940264847)
#     len(np.where(solution)[0]): 15
# ic| iteration: 15
#     valid(solution): np.False_
#     cost(solution): np.float64(70505.47705964162)
#     len(np.where(solution)[0]): 16
# ic| iteration: 16
#     valid(solution): np.False_
#     cost(solution): np.float64(74683.72257985167)
#     len(np.where(solution)[0]): 17
# ic| iteration: 17
#     valid(solution): np.False_
#     cost(solution): np.float64(79024.21621349455)
#     len(np.where(solution)[0]): 18
# ic| iteration: 18
#     valid(solution): np.False_
#     cost(solution): np.float64(83242.38360405454)
#     len(np.where(solution)[0]): 19
# ic| iteration: 19
#     valid(solution): np.False_
#     cost(solution): np.float64(87505.21022629201)
#     len(np.where(solution)[0]): 20
# ic| iteration: 20
#     valid(solution): np.False_
#     cost(solution): np.float64(91742.17629121541)
#     len(np.where(solution)[0]): 21
# ic| iteration: 21
#     valid(solution): np.False_
#     cost(solution): np.float64(95983.84321103666)
#     len(np.where(solution)[0]): 22
# ic| iteration: 22
#     valid(solution): np.True_
#     cost(solution): np.float64(100157.39431320036)
#     len(np.where(solution)[0]): 23
# Greedy solution cost: 100157.39431320036

# %% [markdown]
# *function for hill climbing*

# %%
def fitness(solution):
    """Returns the fitness as -cost, penalizing invalid solutions"""
    return -cost(solution)


# Single mutation tweak (switches one set)
def single_tweak(solution):
    new_solution = solution.copy()
    i = rng.integers(0, NUM_SETS)
    new_solution[i] = not new_solution[i]
    return new_solution

# Multiple tweaks (randomly flips multiple sets)
def multiple_tweak(solution, prob=0.01):
    mask = rng.random(NUM_SETS) < prob
    new_solution = np.logical_xor(solution, mask)
    return new_solution

# %% [markdown]
# **Hill Climbing algorithm single tweak**

# %%
# Hill Climbing algorithm single tweak
def hill_climbing(tweak_function, max_iters=1000):
    solution = rng.random(NUM_SETS) < 0.5  # Start with 50% sets selected
    best_fitness = fitness(solution)

    for iteration in range(max_iters):
        new_solution = tweak_function(solution)
        new_fitness = fitness(new_solution)

        if new_fitness > best_fitness:  # If the new solution is better
            solution = new_solution
            best_fitness = new_fitness

        ic(iteration, valid(solution), cost(solution), len(np.where(solution)[0]))

    return solution, best_fitness

# Running the hill climbing algorithm with single tweak
best_solution, best_fitness = hill_climbing(single_tweak, max_iters=1000)
print(f"Best solution (multiple tweak) cost: {-best_fitness}")
# Out:
# ic| iteration: 0
#     valid(solution): np.True_
#     cost(solution): np.float64(2115481.788239298)
#     len(np.where(solution)[0]): 494
# ic| iteration: 1
#     valid(solution): np.True_
#     cost(solution): np.float64(2115481.788239298)
#     len(np.where(solution)[0]): 494
# ic| iteration: 2
#     valid(solution): np.True_
#     cost(solution): np.float64(2111110.6636611433)
#     len(np.where(solution)[0]): 493
# ic| iteration: 3
#     valid(solution): np.True_
#     cost(solution): np.float64(2111110.6636611433)
#     len(np.where(solution)[0]): 493
# ic| iteration: 4
#     valid(solution): np.True_
#     cost(solution): np.float64(2111110.6636611433)
#     len(np.where(solution)[0]): 493
# ic| iteration: 5
#     valid(solution): np.True_
#     cost(solution): np.float64(2111110.6636611433)
#     len(np.where(solution)[0]): 493
# ic| iteration: 6
#     valid(solution): np.True_
#     cost(solution): np.float64(2106826.6677837856)
#     len(np.where(solution)[0]): 492
# ic| iteration: 7
#     valid(solution): np.True_
#     cost(solution): np.float64(2102514.4314399087)
#     len(np.where(solution)[0]): 491
# ic| iteration: 8
#     valid(solution): np.True_
#     cost(solution): np.float64(2102514.4314399087)
#     len(np.where(solution)[0]): 491
# ic| iteration: 9
#     valid(solution): np.True_
#     cost(solution): np.float64(2102514.4314399087)
#     len(np.where(solution)[0]): 491
# ic| iteration: 10
#     valid(solution): np.True_
#     cost(solution): np.float64(2098317.403456552)
#     len(np.where(solution)[0]): 490
# ic| iteration: 11
#     valid(solution): np.True_
#     cost(solution): np.float64(2098317.403456552)
#     len(np.where(solution)[0]): 490
# ic| iteration: 12
#     valid(solution): np.True_
#     cost(solution): np.float64(2098317.403456552)
#     len(np.where(solution)[0]): 490
# ic| iteration: 13
#     valid(solution): np.True_
#     cost(solution): np.float64(2094035.760189186)
#     len(np.where(solution)[0]): 489
# ic| iteration: 14
#     valid(solution): np.True_
#     cost(solution): np.float64(2089747.0587395253)
#     len(np.where(solution)[0]): 488
# ic| iteration: 15
#     valid(solution): np.True_
#     cost(solution): np.float64(2085286.2860051943)
#     len(np.where(solution)[0]): 487
# ic| iteration: 16
#     valid(solution): np.True_
#     cost(solution): np.float64(2081046.9695720566)
#     len(np.where(solution)[0]): 486
# ic| iteration: 17
#     valid(solution): np.True_
#     cost(solution): np.float64(2076730.0248457328)
#     len(np.where(solution)[0]): 485
# ic| iteration: 18
#     valid(solution): np.True_
#     cost(solution): np.float64(2076730.0248457328)
#     len(np.where(solution)[0]): 485
# ic| iteration: 19
#     valid(solution): np.True_
#     cost(solution): np.float64(2076730.0248457328)
#     len(np.where(solution)[0]): 485
# ic| iteration: 20
#     valid(solution): np.True_
#     cost(solution): np.float64(2076730.0248457328)
#     len(np.where(solution)[0]): 485
# ic| iteration: 21
#     valid(solution): np.True_
#     cost(solution): np.float64(2076730.0248457328)
#     len(np.where(solution)[0]): 485
# ic| iteration: 22
#     valid(solution): np.True_
#     cost(solution): np.float64(2072328.249797)
#     len(np.where(solution)[0]): 484
# ic| iteration: 23
#     valid(solution): np.True_
#     cost(solution): np.float64(2068088.9333638623)
#     len(np.where(solution)[0]): 483
# ic| iteration: 24
#     valid(solution): np.True_
#     cost(solution): np.float64(2063880.1624572964)
#     len(np.where(solution)[0]): 482
# ic| iteration: 25
#     valid(solution): np.True_
#     cost(solution): np.float64(2063880.1624572964)
#     len(np.where(solution)[0]): 482
# ic| iteration: 26
#     valid(solution): np.True_
#     cost(solution): np.float64(2059607.9284542692)
#     len(np.where(solution)[0]): 481
# ic| iteration: 27
#     valid(solution): np.True_
#     cost(solution): np.float64(2059607.9284542692)
#     len(np.where(solution)[0]): 481
# ic| iteration: 28
#     valid(solution): np.True_
#     cost(solution): np.float64(2055476.6054623039)
#     len(np.where(solution)[0]): 480
# ic| iteration: 29
#     valid(solution): np.True_
#     cost(solution): np.float64(2051192.6095849457)
#     len(np.where(solution)[0]): 479
# ic| iteration: 30
#     valid(solution): np.True_
#     cost(solution): np.float64(2046929.7829627085)
#     len(np.where(solution)[0]): 478
# ic| iteration: 31
#     valid(solution): np.True_
#     cost(solution): np.float64(2046929.7829627085)
#     len(np.where(solution)[0]): 478
# ic| iteration: 32
#     valid(solution): np.True_
#     cost(solution): np.float64(2042551.5869280435)
#     len(np.where(solution)[0]): 477
# ic| iteration: 33
#     valid(solution): np.True_
#     cost(solution): np.float64(2042551.5869280435)
#     len(np.where(solution)[0]): 477
# ic| iteration: 34
#     valid(solution): np.True_
#     cost(solution): np.float64(2038208.7377636887)
#     len(np.where(solution)[0]): 476
# ic| iteration: 35
#     valid(solution): np.True_
#     cost(solution): np.float64(2034077.414771723)
#     len(np.where(solution)[0]): 475
# ic| iteration: 36
#     valid(solution): np.True_
#     cost(solution): np.float64(2029873.3413923387)
#     len(np.where(solution)[0]): 474
# ic| iteration: 37
#     valid(solution): np.True_
#     cost(solution): np.float64(2029873.3413923387)
#     len(np.where(solution)[0]): 474
# ic| iteration: 38
#     valid(solution): np.True_
#     cost(solution): np.float64(2029873.3413923387)
#     len(np.where(solution)[0]): 474
# ic| iteration: 39
#     valid(solution): np.True_
#     cost(solution): np.float64(2025713.8706626804)
#     len(np.where(solution)[0]): 473
# ic| iteration: 40
#     valid(solution): np.True_
#     cost(solution): np.float64(2021446.340585704)
#     len(np.where(solution)[0]): 472
# ic| iteration: 41
#     valid(solution): np.True_
#     cost(solution): np.float64(2021446.340585704)
#     len(np.where(solution)[0]): 472
# ic| iteration: 42
#     valid(solution): np.True_
#     cost(solution): np.float64(2021446.340585704)
#     len(np.where(solution)[0]): 472
# ic| iteration: 43
#     valid(solution): np.True_
#     cost(solution): np.float64(2021446.340585704)
#     len(np.where(solution)[0]): 472
# ic| iteration: 44
#     valid(solution): np.True_
#     cost(solution): np.float64(2021446.340585704)
#     len(np.where(solution)[0]): 472
# ic| iteration: 45
#     valid(solution): np.True_
#     cost(solution): np.float64(2017129.3958593798)
#     len(np.where(solution)[0]): 471
# ic| iteration: 46
#     valid(solution): np.True_
#     cost(solution): np.float64(2017129.3958593798)
#     len(np.where(solution)[0]): 471
# ic| iteration: 47
#     valid(solution): np.True_
#     cost(solution): np.float64(2012699.3108340371)
#     len(np.where(solution)[0]): 470
# ic| iteration: 48
#     valid(solution): np.True_
#     cost(solution): np.float64(2008415.314956679)
#     len(np.where(solution)[0]): 469
# ic| iteration: 49
#     valid(solution): np.True_
#     cost(solution): np.float64(2008415.314956679)
#     len(np.where(solution)[0]): 469
# ic| iteration: 50
#     valid(solution): np.True_
#     cost(solution): np.float64(2004046.547299686)
#     len(np.where(solution)[0]): 468
# ic| iteration: 51
#     valid(solution): np.True_
#     cost(solution): np.float64(2004046.547299686)
#     len(np.where(solution)[0]): 468
# ic| iteration: 52
#     valid(solution): np.True_
#     cost(solution): np.float64(1999729.6025733622)
#     len(np.where(solution)[0]): 467
# ic| iteration: 53
#     valid(solution): np.True_
#     cost(solution): np.float64(1999729.6025733622)
#     len(np.where(solution)[0]): 467
# ic| iteration: 54
#     valid(solution): np.True_
#     cost(solution): np.float64(1995605.31379717)
#     len(np.where(solution)[0]): 466
# ic| iteration: 55
#     valid(solution): np.True_
#     cost(solution): np.float64(1991318.965192363)
#     len(np.where(solution)[0]): 465
# ic| iteration: 56
#     valid(solution): np.True_
#     cost(solution): np.float64(1991318.965192363)
#     len(np.where(solution)[0]): 465
# ic| iteration: 57
#     valid(solution): np.True_
#     cost(solution): np.float64(1991318.965192363)
#     len(np.where(solution)[0]): 465
# ic| iteration: 58
#     valid(solution): np.True_
#     cost(solution): np.float64(1987133.6771460907)
#     len(np.where(solution)[0]): 464
# ic| iteration: 59
#     valid(solution): np.True_
#     cost(solution): np.float64(1987133.6771460907)
#     len(np.where(solution)[0]): 464
# ic| iteration: 60
#     valid(solution): np.True_
#     cost(solution): np.float64(1987133.6771460907)
#     len(np.where(solution)[0]): 464
# ic| iteration: 61
#     valid(solution): np.True_
#     cost(solution): np.float64(1982840.2696547194)
#     len(np.where(solution)[0]): 463
# ic| iteration: 62
#     valid(solution): np.True_
#     cost(solution): np.float64(1978694.8749658042)
#     len(np.where(solution)[0]): 462
# ic| iteration: 63
#     valid(solution): np.True_
#     cost(solution): np.float64(1974457.9089008807)
#     len(np.where(solution)[0]): 461
# ic| iteration: 64
#     valid(solution): np.True_
#     cost(solution): np.float64(1974457.9089008807)
#     len(np.where(solution)[0]): 461
# ic| iteration: 65
#     valid(solution): np.True_
#     cost(solution): np.float64(1970188.0269197663)
#     len(np.where(solution)[0]): 460
# ic| iteration: 66
#     valid(solution): np.True_
#     cost(solution): np.float64(1965779.1759243654)
#     len(np.where(solution)[0]): 459
# ic| iteration: 67
#     valid(solution): np.True_
#     cost(solution): np.float64(1961509.293943251)
#     len(np.where(solution)[0]): 458
# ic| iteration: 68
#     valid(solution): np.True_
#     cost(solution): np.float64(1961509.293943251)
#     len(np.where(solution)[0]): 458
# ic| iteration: 69
#     valid(solution): np.True_
#     cost(solution): np.float64(1961509.293943251)
#     len(np.where(solution)[0]): 458
# ic| iteration: 70
#     valid(solution): np.True_
#     cost(solution): np.float64(1957213.5332551287)
#     len(np.where(solution)[0]): 457
# ic| iteration: 71
#     valid(solution): np.True_
#     cost(solution): np.float64(1957213.5332551287)
#     len(np.where(solution)[0]): 457
# ic| iteration: 72
#     valid(solution): np.True_
#     cost(solution): np.float64(1953042.329182024)
#     len(np.where(solution)[0]): 456
# ic| iteration: 73
#     valid(solution): np.True_
#     cost(solution): np.float64(1953042.329182024)
#     len(np.where(solution)[0]): 456
# ic| iteration: 74
#     valid(solution): np.True_
#     cost(solution): np.float64(1948793.6100918746)
#     len(np.where(solution)[0]): 455
# ic| iteration: 75
#     valid(solution): np.True_
#     cost(solution): np.float64(1948793.6100918746)
#     len(np.where(solution)[0]): 455
# ic| iteration: 76
#     valid(solution): np.True_
#     cost(solution): np.float64(1948793.6100918746)
#     len(np.where(solution)[0]): 455
# ic| iteration: 77
#     valid(solution): np.True_
#     cost(solution): np.float64(1944436.62530583)
#     len(np.where(solution)[0]): 454
# ic| iteration: 78
#     valid(solution): np.True_
#     cost(solution): np.float64(1940312.3365296382)
#     len(np.where(solution)[0]): 453
# ic| iteration: 79
#     valid(solution): np.True_
#     cost(solution): np.float64(1940312.3365296382)
#     len(np.where(solution)[0]): 453
# ic| iteration: 80
#     valid(solution): np.True_
#     cost(solution): np.float64(1936000.1001857612)
#     len(np.where(solution)[0]): 452
# ic| iteration: 81
#     valid(solution): np.True_
#     cost(solution): np.float64(1936000.1001857612)
#     len(np.where(solution)[0]): 452
# ic| iteration: 82
#     valid(solution): np.True_
#     cost(solution): np.float64(1931850.013965313)
#     len(np.where(solution)[0]): 451
# ic| iteration: 83
#     valid(solution): np.True_
#     cost(solution): np.float64(1927509.5203316703)
#     len(np.where(solution)[0]): 450
# ic| iteration: 84
#     valid(solution): np.True_
#     cost(solution): np.float64(1923223.1717268631)
#     len(np.where(solution)[0]): 449
# ic| iteration: 85
#     valid(solution): np.True_
#     cost(solution): np.float64(1918847.3329598214)
#     len(np.where(solution)[0]): 448
# ic| iteration: 86
#     valid(solution): np.True_
#     cost(solution): np.float64(1914605.66604)
#     len(np.where(solution)[0]): 447
# ic| iteration: 87
#     valid(solution): np.True_
#     cost(solution): np.float64(1914605.66604)
#     len(np.where(solution)[0]): 447
# ic| iteration: 88
#     valid(solution): np.True_
#     cost(solution): np.float64(1914605.66604)
#     len(np.where(solution)[0]): 447
# ic| iteration: 89
#     valid(solution): np.True_
#     cost(solution): np.float64(1910382.799693497)
#     len(np.where(solution)[0]): 446
# ic| iteration: 90
#     valid(solution): np.True_
#     cost(solution): np.float64(1906096.4510886897)
#     len(np.where(solution)[0]): 445
# ic| iteration: 91
#     valid(solution): np.True_
#     cost(solution): np.float64(1906096.4510886897)
#     len(np.where(solution)[0]): 445
# ic| iteration: 92
#     valid(solution): np.True_
#     cost(solution): np.float64(1906096.4510886897)
#     len(np.where(solution)[0]): 445
# ic| iteration: 93
#     valid(solution): np.True_
#     cost(solution): np.float64(1906096.4510886897)
#     len(np.where(solution)[0]): 445
# ic| iteration: 94
#     valid(solution): np.True_
#     cost(solution): np.float64(1901904.1194388848)
#     len(np.where(solution)[0]): 444
# ic| iteration: 95
#     valid(solution): np.True_
#     cost(solution): np.float64(1897829.0395536793)
#     len(np.where(solution)[0]): 443
# ic| iteration: 96
#     valid(solution): np.True_
#     cost(solution): np.float64(1897829.0395536793)
#     len(np.where(solution)[0]): 443
# ic| iteration: 97
#     valid(solution): np.True_
#     cost(solution): np.float64(1893514.4490769668)
#     len(np.where(solution)[0]): 442
# ic| iteration: 98
#     valid(solution): np.True_
#     cost(solution): np.float64(1893514.4490769668)
#     len(np.where(solution)[0]): 442
# ic| iteration: 99
#     valid(solution): np.True_
#     cost(solution): np.float64(1889444.0529468292)
#     len(np.where(solution)[0]): 441
# ic| iteration: 100
#     valid(solution): np.True_
#     cost(solution): np.float64(1885338.5167439317)
#     len(np.where(solution)[0]): 440
# ic| iteration: 101
#     valid(solution): np.True_
#     cost(solution): np.float64(1881141.488760575)
#     len(np.where(solution)[0]): 439
# ic| iteration: 102
#     valid(solution): np.True_
#     cost(solution): np.float64(1881141.488760575)
#     len(np.where(solution)[0]): 439
# ic| iteration: 103
#     valid(solution): np.True_
#     cost(solution): np.float64(1876878.6621383375)
#     len(np.where(solution)[0]): 438
# ic| iteration: 104
#     valid(solution): np.True_
#     cost(solution): np.float64(1876878.6621383375)
#     len(np.where(solution)[0]): 438
# ic| iteration: 105
#     valid(solution): np.True_
#     cost(solution): np.float64(1872448.5771129946)
#     len(np.where(solution)[0]): 437
# ic| iteration: 106
#     valid(solution): np.True_
#     cost(solution): np.float64(1868152.816424872)
#     len(np.where(solution)[0]): 436
# ic| iteration: 107
#     valid(solution): np.True_
#     cost(solution): np.float64(1868152.816424872)
#     len(np.where(solution)[0]): 436
# ic| iteration: 108
#     valid(solution): np.True_
#     cost(solution): np.float64(1868152.816424872)
#     len(np.where(solution)[0]): 436
# ic| iteration: 109
#     valid(solution): np.True_
#     cost(solution): np.float64(1868152.816424872)
#     len(np.where(solution)[0]): 436
# ic| iteration: 110
#     valid(solution): np.True_
#     cost(solution): np.float64(1863835.871698548)
#     len(np.where(solution)[0]): 435
# ic| iteration: 111
#     valid(solution): np.True_
#     cost(solution): np.float64(1863835.871698548)
#     len(np.where(solution)[0]): 435
# ic| iteration: 112
#     valid(solution): np.True_
#     cost(solution): np.float64(1859551.8758211904)
#     len(np.where(solution)[0]): 434
# ic| iteration: 113
#     valid(solution): np.True_
#     cost(solution): np.float64(1859551.8758211904)
#     len(np.where(solution)[0]): 434
# ic| iteration: 114
#     valid(solution): np.True_
#     cost(solution): np.float64(1859551.8758211904)
#     len(np.where(solution)[0]): 434
# ic| iteration: 115
#     valid(solution): np.True_
#     cost(solution): np.float64(1855053.3072468094)
#     len(np.where(solution)[0]): 433
# ic| iteration: 116
#     valid(solution): np.True_
#     cost(solution): np.float64(1855053.3072468094)
#     len(np.where(solution)[0]): 433
# ic| iteration: 117
#     valid(solution): np.True_
#     cost(solution): np.float64(1855053.3072468094)
#     len(np.where(solution)[0]): 433
# ic| iteration: 118
#     valid(solution): np.True_
#     cost(solution): np.float64(1850618.5022898014)
#     len(np.where(solution)[0]): 432
# ic| iteration: 119
#     valid(solution): np.True_
#     cost(solution): np.float64(1850618.5022898014)
#     len(np.where(solution)[0]): 432
# ic| iteration: 120
#     valid(solution): np.True_
#     cost(solution): np.float64(1846409.7313832352)
#     len(np.where(solution)[0]): 431
# ic| iteration: 121
#     valid(solution): np.True_
#     cost(solution): np.float64(1842226.7909654428)
#     len(np.where(solution)[0]): 430
# ic| iteration: 122
#     valid(solution): np.True_
#     cost(solution): np.float64(1842226.7909654428)
#     len(np.where(solution)[0]): 430
# ic| iteration: 123
#     valid(solution): np.True_
#     cost(solution): np.float64(1842226.7909654428)
#     len(np.where(solution)[0]): 430
# ic| iteration: 124
#     valid(solution): np.True_
#     cost(solution): np.float64(1842226.7909654428)
#     len(np.where(solution)[0]): 430
# ic| iteration: 125
#     valid(solution): np.True_
#     cost(solution): np.float64(1842226.7909654428)
#     len(np.where(solution)[0]): 430
# ic| iteration: 126
#     valid(solution): np.True_
#     cost(solution): np.float64(1842226.7909654428)
#     len(np.where(solution)[0]): 430
# ic| iteration: 127
#     valid(solution): np.True_
#     cost(solution): np.float64(1842226.7909654428)
#     len(np.where(solution)[0]): 430
# ic| iteration: 128
#     valid(solution): np.True_
#     cost(solution): np.float64(1842226.7909654428)
#     len(np.where(solution)[0]): 430
# ic| iteration: 129
#     valid(solution): np.True_
#     cost(solution): np.float64(1837978.0718752933)
#     len(np.where(solution)[0]): 429
# ic| iteration: 130
#     valid(solution): np.True_
#     cost(solution): np.float64(1837978.0718752933)
#     len(np.where(solution)[0]): 429
# ic| iteration: 131
#     valid(solution): np.True_
#     cost(solution): np.float64(1833672.8972287504)
#     len(np.where(solution)[0]): 428
# ic| iteration: 132
#     valid(solution): np.True_
#     cost(solution): np.float64(1833672.8972287504)
#     len(np.where(solution)[0]): 428
# ic| iteration: 133
#     valid(solution): np.True_
#     cost(solution): np.float64(1833672.8972287504)
#     len(np.where(solution)[0]): 428
# ic| iteration: 134
#     valid(solution): np.True_
#     cost(solution): np.float64(1833672.8972287504)
#     len(np.where(solution)[0]): 428
# ic| iteration: 135
#     valid(solution): np.True_
#     cost(solution): np.float64(1829346.534337269)
#     len(np.where(solution)[0]): 427
# ic| iteration: 136
#     valid(solution): np.True_
#     cost(solution): np.float64(1824930.606362641)
#     len(np.where(solution)[0]): 426
# ic| iteration: 137
#     valid(solution): np.True_
#     cost(solution): np.float64(1824930.606362641)
#     len(np.where(solution)[0]): 426
# ic| iteration: 138
#     valid(solution): np.True_
#     cost(solution): np.float64(1820547.6954466237)
#     len(np.where(solution)[0]): 425
# ic| iteration: 139
#     valid(solution): np.True_
#     cost(solution): np.float64(1820547.6954466237)
#     len(np.where(solution)[0]): 425
# ic| iteration: 140
#     valid(solution): np.True_
#     cost(solution): np.float64(1820547.6954466237)
#     len(np.where(solution)[0]): 425
# ic| iteration: 141
#     valid(solution): np.True_
#     cost(solution): np.float64(1820547.6954466237)
#     len(np.where(solution)[0]): 425
# ic| iteration: 142
#     valid(solution): np.True_
#     cost(solution): np.float64(1820547.6954466237)
#     len(np.where(solution)[0]): 425
# ic| iteration: 143
#     valid(solution): np.True_
#     cost(solution): np.float64(1816169.4994119587)
#     len(np.where(solution)[0]): 424
# ic| iteration: 144
#     valid(solution): np.True_
#     cost(solution): np.float64(1816169.4994119587)
#     len(np.where(solution)[0]): 424
# ic| iteration: 145
#     valid(solution): np.True_
#     cost(solution): np.float64(1811887.856144593)
#     len(np.where(solution)[0]): 423
# ic| iteration: 146
#     valid(solution): np.True_
#     cost(solution): np.float64(1811887.856144593)
#     len(np.where(solution)[0]): 423
# ic| iteration: 147
#     valid(solution): np.True_
#     cost(solution): np.float64(1811887.856144593)
#     len(np.where(solution)[0]): 423
# ic| iteration: 148
#     valid(solution): np.True_
#     cost(solution): np.float64(1807632.0838198233)
#     len(np.where(solution)[0]): 422
# ic| iteration: 149
#     valid(solution): np.True_
#     cost(solution): np.float64(1807632.0838198233)
#     len(np.where(solution)[0]): 422
# ic| iteration: 150
#     valid(solution): np.True_
#     cost(solution): np.float64(1807632.0838198233)
#     len(np.where(solution)[0]): 422
# ic| iteration: 151
#     valid(solution): np.True_
#     cost(solution): np.float64(1803453.8382996134)
#     len(np.where(solution)[0]): 421
# ic| iteration: 152
#     valid(solution): np.True_
#     cost(solution): np.float64(1799212.1713797923)
#     len(np.where(solution)[0]): 420
# ic| iteration: 153
#     valid(solution): np.True_
#     cost(solution): np.float64(1799212.1713797923)
#     len(np.where(solution)[0]): 420
# ic| iteration: 154
#     valid(solution): np.True_
#     cost(solution): np.float64(1794977.5555645602)
#     len(np.where(solution)[0]): 419
# ic| iteration: 155
#     valid(solution): np.True_
#     cost(solution): np.float64(1790528.588073848)
#     len(np.where(solution)[0]): 418
# ic| iteration: 156
#     valid(solution): np.True_
#     cost(solution): np.float64(1786107.9415400946)
#     len(np.where(solution)[0]): 417
# ic| iteration: 157
#     valid(solution): np.True_
#     cost(solution): np.float64(1781866.2746202732)
#     len(np.where(solution)[0]): 416
# ic| iteration: 158
#     valid(solution): np.True_
#     cost(solution): np.float64(1781866.2746202732)
#     len(np.where(solution)[0]): 416
# ic| iteration: 159
#     valid(solution): np.True_
#     cost(solution): np.float64(1777655.1547713312)
#     len(np.where(solution)[0]): 415
# ic| iteration: 160
#     valid(solution): np.True_
#     cost(solution): np.float64(1773331.1465960417)
#     len(np.where(solution)[0]): 414
# ic| iteration: 161
#     valid(solution): np.True_
#     cost(solution): np.float64(1773331.1465960417)
#     len(np.where(solution)[0]): 414
# ic| iteration: 162
#     valid(solution): np.True_
#     cost(solution): np.float64(1769108.2802495384)
#     len(np.where(solution)[0]): 413
# ic| iteration: 163
#     valid(solution): np.True_
#     cost(solution): np.float64(1764640.423005023)
#     len(np.where(solution)[0]): 412
# ic| iteration: 164
#     valid(solution): np.True_
#     cost(solution): np.float64(1764640.423005023)
#     len(np.where(solution)[0]): 412
# ic| iteration: 165
#     valid(solution): np.True_
#     cost(solution): np.float64(1760368.189001996)
#     len(np.where(solution)[0]): 411
# ic| iteration: 166
#     valid(solution): np.True_
#     cost(solution): np.float64(1760368.189001996)
#     len(np.where(solution)[0]): 411
# ic| iteration: 167
#     valid(solution): np.True_
#     cost(solution): np.float64(1755952.2610273685)
#     len(np.where(solution)[0]): 410
# ic| iteration: 168
#     valid(solution): np.True_
#     cost(solution): np.float64(1755952.2610273685)
#     len(np.where(solution)[0]): 410
# ic| iteration: 169
#     valid(solution): np.True_
#     cost(solution): np.float64(1751736.442936375)
#     len(np.where(solution)[0]): 409
# ic| iteration: 170
#     valid(solution): np.True_
#     cost(solution): np.float64(1747461.8567937133)
#     len(np.where(solution)[0]): 408
# ic| iteration: 171
#     valid(solution): np.True_
#     cost(solution): np.float64(1747461.8567937133)
#     len(np.where(solution)[0]): 408
# ic| iteration: 172
#     valid(solution): np.True_
#     cost(solution): np.float64(1743170.8023818468)
#     len(np.where(solution)[0]): 407
# ic| iteration: 173
#     valid(solution): np.True_
#     cost(solution): np.float64(1743170.8023818468)
#     len(np.where(solution)[0]): 407
# ic| iteration: 174
#     valid(solution): np.True_
#     cost(solution): np.float64(1743170.8023818468)
#     len(np.where(solution)[0]): 407
# ic| iteration: 175
#     valid(solution): np.True_
#     cost(solution): np.float64(1743170.8023818468)
#     len(np.where(solution)[0]): 407
# ic| iteration: 176
#     valid(solution): np.True_
#     cost(solution): np.float64(1743170.8023818468)
#     len(np.where(solution)[0]): 407
# ic| iteration: 177
#     valid(solution): np.True_
#     cost(solution): np.float64(1743170.8023818468)
#     len(np.where(solution)[0]): 407
# ic| iteration: 178
#     valid(solution): np.True_
#     cost(solution): np.float64(1743170.8023818468)
#     len(np.where(solution)[0]): 407
# ic| iteration: 179
#     valid(solution): np.True_
#     cost(solution): np.float64(1743170.8023818468)
#     len(np.where(solution)[0]): 407
# ic| iteration: 180
#     valid(solution): np.True_
#     cost(solution): np.float64(1743170.8023818468)
#     len(np.where(solution)[0]): 407
# ic| iteration: 181
#     valid(solution): np.True_
#     cost(solution): np.float64(1743170.8023818468)
#     len(np.where(solution)[0]): 407
# ic| iteration: 182
#     valid(solution): np.True_
#     cost(solution): np.float64(1738870.3349486922)
#     len(np.where(solution)[0]): 406
# ic| iteration: 183
#     valid(solution): np.True_
#     cost(solution): np.float64(1738870.3349486922)
#     len(np.where(solution)[0]): 406
# ic| iteration: 184
#     valid(solution): np.True_
#     cost(solution): np.float64(1734609.8598769493)
#     len(np.where(solution)[0]): 405
# ic| iteration: 185
#     valid(solution): np.True_
#     cost(solution): np.float64(1730429.2669678626)
#     len(np.where(solution)[0]): 404
# ic| iteration: 186
#     valid(solution): np.True_
#     cost(solution): np.float64(1730429.2669678626)
#     len(np.where(solution)[0]): 404
# ic| iteration: 187
#     valid(solution): np.True_
#     cost(solution): np.float64(1730429.2669678626)
#     len(np.where(solution)[0]): 404
# ic| iteration: 188
#     valid(solution): np.True_
#     cost(solution): np.float64(1730429.2669678626)
#     len(np.where(solution)[0]): 404
# ic| iteration: 189
#     valid(solution): np.True_
#     cost(solution): np.float64(1730429.2669678626)
#     len(np.where(solution)[0]): 404
# ic| iteration: 190
#     valid(solution): np.True_
#     cost(solution): np.float64(1725980.2994771504)
#     len(np.where(solution)[0]): 403
# ic| iteration: 191
#     valid(solution): np.True_
#     cost(solution): np.float64(1721651.5817529615)
#     len(np.where(solution)[0]): 402
# ic| iteration: 192
#     valid(solution): np.True_
#     cost(solution): np.float64(1721651.5817529615)
#     len(np.where(solution)[0]): 402
# ic| iteration: 193
#     valid(solution): np.True_
#     cost(solution): np.float64(1721651.5817529615)
#     len(np.where(solution)[0]): 402
# ic| iteration: 194
#     valid(solution): np.True_
#     cost(solution): np.float64(1717282.8140959684)
#     len(np.where(solution)[0]): 401
# ic| iteration: 195
#     valid(solution): np.True_
#     cost(solution): np.float64(1717282.8140959684)
#     len(np.where(solution)[0]): 401
# ic| iteration: 196
#     valid(solution): np.True_
#     cost(solution): np.float64(1712843.2887505786)
#     len(np.where(solution)[0]): 400
# ic| iteration: 197
#     valid(solution): np.True_
#     cost(solution): np.float64(1708625.1213600184)
#     len(np.where(solution)[0]): 399
# ic| iteration: 198
#     valid(solution): np.True_
#     cost(solution): np.float64(1708625.1213600184)
#     len(np.where(solution)[0]): 399
# ic| iteration: 199
#     valid(solution): np.True_
#     cost(solution): np.float64(1708625.1213600184)
#     len(np.where(solution)[0]): 399
# ic| iteration: 200
#     valid(solution): np.True_
#     cost(solution): np.float64(1708625.1213600184)
#     len(np.where(solution)[0]): 399
# ic| iteration: 201
#     valid(solution): np.True_
#     cost(solution): np.float64(1708625.1213600184)
#     len(np.where(solution)[0]): 399
# ic| iteration: 202
#     valid(solution): np.True_
#     cost(solution): np.float64(1708625.1213600184)
#     len(np.where(solution)[0]): 399
# ic| iteration: 203
#     valid(solution): np.True_
#     cost(solution): np.float64(1704376.4022698689)
#     len(np.where(solution)[0]): 398
# ic| iteration: 204
#     valid(solution): np.True_
#     cost(solution): np.float64(1699998.206235204)
#     len(np.where(solution)[0]): 397
# ic| iteration: 205
#     valid(solution): np.True_
#     cost(solution): np.float64(1699998.206235204)
#     len(np.where(solution)[0]): 397
# ic| iteration: 206
#     valid(solution): np.True_
#     cost(solution): np.float64(1695761.2401702807)
#     len(np.where(solution)[0]): 396
# ic| iteration: 207
#     valid(solution): np.True_
#     cost(solution): np.float64(1691267.3976599397)
#     len(np.where(solution)[0]): 395
# ic| iteration: 208
#     valid(solution): np.True_
#     cost(solution): np.float64(1687119.6572655602)
#     len(np.where(solution)[0]): 394
# ic| iteration: 209
#     valid(solution): np.True_
#     cost(solution): np.float64(1687119.6572655602)
#     len(np.where(solution)[0]): 394
# ic| iteration: 210
#     valid(solution): np.True_
#     cost(solution): np.float64(1682809.774937692)
#     len(np.where(solution)[0]): 393
# ic| iteration: 211
#     valid(solution): np.True_
#     cost(solution): np.float64(1682809.774937692)
#     len(np.where(solution)[0]): 393
# ic| iteration: 212
#     valid(solution): np.True_
#     cost(solution): np.float64(1678516.3674463208)
#     len(np.where(solution)[0]): 392
# ic| iteration: 213
#     valid(solution): np.True_
#     cost(solution): np.float64(1678516.3674463208)
#     len(np.where(solution)[0]): 392
# ic| iteration: 214
#     valid(solution): np.True_
#     cost(solution): np.float64(1678516.3674463208)
#     len(np.where(solution)[0]): 392
# ic| iteration: 215
#     valid(solution): np.True_
#     cost(solution): np.float64(1674373.3183422089)
#     len(np.where(solution)[0]): 391
# ic| iteration: 216
#     valid(solution): np.True_
#     cost(solution): np.float64(1674373.3183422089)
#     len(np.where(solution)[0]): 391
# ic| iteration: 217
#     valid(solution): np.True_
#     cost(solution): np.float64(1674373.3183422089)
#     len(np.where(solution)[0]): 391
# ic| iteration: 218
#     valid(solution): np.True_
#     cost(solution): np.float64(1674373.3183422089)
#     len(np.where(solution)[0]): 391
# ic| iteration: 219
#     valid(solution): np.True_
#     cost(solution): np.float64(1674373.3183422089)
#     len(np.where(solution)[0]): 391
# ic| iteration: 220
#     valid(solution): np.True_
#     cost(solution): np.float64(1670013.9772134596)
#     len(np.where(solution)[0]): 390
# ic| iteration: 221
#     valid(solution): np.True_
#     cost(solution): np.float64(1670013.9772134596)
#     len(np.where(solution)[0]): 390
# ic| iteration: 222
#     valid(solution): np.True_
#     cost(solution): np.float64(1670013.9772134596)
#     len(np.where(solution)[0]): 390
# ic| iteration: 223
#     valid(solution): np.True_
#     cost(solution): np.float64(1670013.9772134596)
#     len(np.where(solution)[0]): 390
# ic| iteration: 224
#     valid(solution): np.True_
#     cost(solution): np.float64(1670013.9772134596)
#     len(np.where(solution)[0]): 390
# ic| iteration: 225
#     valid(solution): np.True_
#     cost(solution): np.float64(1670013.9772134596)
#     len(np.where(solution)[0]): 390
# ic| iteration: 226
#     valid(solution): np.True_
#     cost(solution): np.float64(1670013.9772134596)
#     len(np.where(solution)[0]): 390
# ic| iteration: 227
#     valid(solution): np.True_
#     cost(solution): np.float64(1665729.9813361017)
#     len(np.where(solution)[0]): 389
# ic| iteration: 228
#     valid(solution): np.True_
#     cost(solution): np.float64(1665729.9813361017)
#     len(np.where(solution)[0]): 389
# ic| iteration: 229
#     valid(solution): np.True_
#     cost(solution): np.float64(1665729.9813361017)
#     len(np.where(solution)[0]): 389
# ic| iteration: 230
#     valid(solution): np.True_
#     cost(solution): np.float64(1665729.9813361017)
#     len(np.where(solution)[0]): 389
# ic| iteration: 231
#     valid(solution): np.True_
#     cost(solution): np.float64(1665729.9813361017)
#     len(np.where(solution)[0]): 389
# ic| iteration: 232
#     valid(solution): np.True_
#     cost(solution): np.float64(1661493.0152711784)
#     len(np.where(solution)[0]): 388
# ic| iteration: 233
#     valid(solution): np.True_
#     cost(solution): np.float64(1661493.0152711784)
#     len(np.where(solution)[0]): 388
# ic| iteration: 234
#     valid(solution): np.True_
#     cost(solution): np.float64(1661493.0152711784)
#     len(np.where(solution)[0]): 388
# ic| iteration: 235
#     valid(solution): np.True_
#     cost(solution): np.float64(1661493.0152711784)
#     len(np.where(solution)[0]): 388
# ic| iteration: 236
#     valid(solution): np.True_
#     cost(solution): np.float64(1661493.0152711784)
#     len(np.where(solution)[0]): 388
# ic| iteration: 237
#     valid(solution): np.True_
#     cost(solution): np.float64(1661493.0152711784)
#     len(np.where(solution)[0]): 388
# ic| iteration: 238
#     valid(solution): np.True_
#     cost(solution): np.float64(1657305.3794767074)
#     len(np.where(solution)[0]): 387
# ic| iteration: 239
#     valid(solution): np.True_
#     cost(solution): np.float64(1657305.3794767074)
#     len(np.where(solution)[0]): 387
# ic| iteration: 240
#     valid(solution): np.True_
#     cost(solution): np.float64(1653026.0887018237)
#     len(np.where(solution)[0]): 386
# ic| iteration: 241
#     valid(solution): np.True_
#     cost(solution): np.float64(1653026.0887018237)
#     len(np.where(solution)[0]): 386
# ic| iteration: 242
#     valid(solution): np.True_
#     cost(solution): np.float64(1653026.0887018237)
#     len(np.where(solution)[0]): 386
# ic| iteration: 243
#     valid(solution): np.True_
#     cost(solution): np.float64(1653026.0887018237)
#     len(np.where(solution)[0]): 386
# ic| iteration: 244
#     valid(solution): np.True_
#     cost(solution): np.float64(1653026.0887018237)
#     len(np.where(solution)[0]): 386
# ic| iteration: 245
#     valid(solution): np.True_
#     cost(solution): np.float64(1653026.0887018237)
#     len(np.where(solution)[0]): 386
# ic| iteration: 246
#     valid(solution): np.True_
#     cost(solution): np.float64(1653026.0887018237)
#     len(np.where(solution)[0]): 386
# ic| iteration: 247
#     valid(solution): np.True_
#     cost(solution): np.float64(1648789.1226369003)
#     len(np.where(solution)[0]): 385
# ic| iteration: 248
#     valid(solution): np.True_
#     cost(solution): np.float64(1648789.1226369003)
#     len(np.where(solution)[0]): 385
# ic| iteration: 249
#     valid(solution): np.True_
#     cost(solution): np.float64(1648789.1226369003)
#     len(np.where(solution)[0]): 385
# ic| iteration: 250
#     valid(solution): np.True_
#     cost(solution): np.float64(1648789.1226369003)
#     len(np.where(solution)[0]): 385
# ic| iteration: 251
#     valid(solution): np.True_
#     cost(solution): np.float64(1648789.1226369003)
#     len(np.where(solution)[0]): 385
# ic| iteration: 252
#     valid(solution): np.True_
#     cost(solution): np.float64(1644427.4250496528)
#     len(np.where(solution)[0]): 384
# ic| iteration: 253
#     valid(solution): np.True_
#     cost(solution): np.float64(1640342.976186432)
#     len(np.where(solution)[0]): 383
# ic| iteration: 254
#     valid(solution): np.True_
#     cost(solution): np.float64(1640342.976186432)
#     len(np.where(solution)[0]): 383
# ic| iteration: 255
#     valid(solution): np.True_
#     cost(solution): np.float64(1640342.976186432)
#     len(np.where(solution)[0]): 383
# ic| iteration: 256
#     valid(solution): np.True_
#     cost(solution): np.float64(1640342.976186432)
#     len(np.where(solution)[0]): 383
# ic| iteration: 257
#     valid(solution): np.True_
#     cost(solution): np.float64(1635948.2760504517)
#     len(np.where(solution)[0]): 382
# ic| iteration: 258
#     valid(solution): np.True_
#     cost(solution): np.float64(1631548.8594209168)
#     len(np.where(solution)[0]): 381
# ic| iteration: 259
#     valid(solution): np.True_
#     cost(solution): np.float64(1627255.4519295455)
#     len(np.where(solution)[0]): 380
# ic| iteration: 260
#     valid(solution): np.True_
#     cost(solution): np.float64(1622985.569948431)
#     len(np.where(solution)[0]): 379
# ic| iteration: 261
#     valid(solution): np.True_
#     cost(solution): np.float64(1618856.5918161287)
#     len(np.where(solution)[0]): 378
# ic| iteration: 262
#     valid(solution): np.True_
#     cost(solution): np.float64(1618856.5918161287)
#     len(np.where(solution)[0]): 378
# ic| iteration: 263
#     valid(solution): np.True_
#     cost(solution): np.float64(1614629.0260382954)
#     len(np.where(solution)[0]): 377
# ic| iteration: 264
#     valid(solution): np.True_
#     cost(solution): np.float64(1610394.4102230635)
#     len(np.where(solution)[0]): 376
# ic| iteration: 265
#     valid(solution): np.True_
#     cost(solution): np.float64(1610394.4102230635)
#     len(np.where(solution)[0]): 376
# ic| iteration: 266
#     valid(solution): np.True_
#     cost(solution): np.float64(1606263.087231098)
#     len(np.where(solution)[0]): 375
# ic| iteration: 267
#     valid(solution): np.True_
#     cost(solution): np.float64(1606263.087231098)
#     len(np.where(solution)[0]): 375
# ic| iteration: 268
#     valid(solution): np.True_
#     cost(solution): np.float64(1606263.087231098)
#     len(np.where(solution)[0]): 375
# ic| iteration: 269
#     valid(solution): np.True_
#     cost(solution): np.float64(1606263.087231098)
#     len(np.where(solution)[0]): 375
# ic| iteration: 270
#     valid(solution): np.True_
#     cost(solution): np.float64(1606263.087231098)
#     len(np.where(solution)[0]): 375
# ic| iteration: 271
#     valid(solution): np.True_
#     cost(solution): np.float64(1602040.2208845946)
#     len(np.where(solution)[0]): 374
# ic| iteration: 272
#     valid(solution): np.True_
#     cost(solution): np.float64(1597810.3052129615)
#     len(np.where(solution)[0]): 373
# ic| iteration: 273
#     valid(solution): np.True_
#     cost(solution): np.float64(1597810.3052129615)
#     len(np.where(solution)[0]): 373
# ic| iteration: 274
#     valid(solution): np.True_
#     cost(solution): np.float64(1597810.3052129615)
#     len(np.where(solution)[0]): 373
# ic| iteration: 275
#     valid(solution): np.True_
#     cost(solution): np.float64(1593538.0712099345)
#     len(np.where(solution)[0]): 372
# ic| iteration: 276
#     valid(solution): np.True_
#     cost(solution): np.float64(1589310.5054321012)
#     len(np.where(solution)[0]): 371
# ic| iteration: 277
#     valid(solution): np.True_
#     cost(solution): np.float64(1589310.5054321012)
#     len(np.where(solution)[0]): 371
# ic| iteration: 278
#     valid(solution): np.True_
#     cost(solution): np.float64(1585052.3817928655)
#     len(np.where(solution)[0]): 370
# ic| iteration: 279
#     valid(solution): np.True_
#     cost(solution): np.float64(1580838.9128824293)
#     len(np.where(solution)[0]): 369
# ic| iteration: 280
#     valid(solution): np.True_
#     cost(solution): np.float64(1576399.3875370396)
#     len(np.where(solution)[0]): 368
# ic| iteration: 281
#     valid(solution): np.True_
#     cost(solution): np.float64(1576399.3875370396)
#     len(np.where(solution)[0]): 368
# ic| iteration: 282
#     valid(solution): np.True_
#     cost(solution): np.float64(1576399.3875370396)
#     len(np.where(solution)[0]): 368
# ic| iteration: 283
#     valid(solution): np.True_
#     cost(solution): np.float64(1572253.9928481244)
#     len(np.where(solution)[0]): 367
# ic| iteration: 284
#     valid(solution): np.True_
#     cost(solution): np.float64(1572253.9928481244)
#     len(np.where(solution)[0]): 367
# ic| iteration: 285
#     valid(solution): np.True_
#     cost(solution): np.float64(1572253.9928481244)
#     len(np.where(solution)[0]): 367
# ic| iteration: 286
#     valid(solution): np.True_
#     cost(solution): np.float64(1568087.4824729343)
#     len(np.where(solution)[0]): 366
# ic| iteration: 287
#     valid(solution): np.True_
#     cost(solution): np.float64(1563789.3684708667)
#     len(np.where(solution)[0]): 365
# ic| iteration: 288
#     valid(solution): np.True_
#     cost(solution): np.float64(1563789.3684708667)
#     len(np.where(solution)[0]): 365
# ic| iteration: 289
#     valid(solution): np.True_
#     cost(solution): np.float64(1559622.8580956766)
#     len(np.where(solution)[0]): 364
# ic| iteration: 290
#     valid(solution): np.True_
#     cost(solution): np.float64(1559622.8580956766)
#     len(np.where(solution)[0]): 364
# ic| iteration: 291
#     valid(solution): np.True_
#     cost(solution): np.float64(1555449.3069935131)
#     len(np.where(solution)[0]): 363
# ic| iteration: 292
#     valid(solution): np.True_
#     cost(solution): np.float64(1551167.6637261473)
#     len(np.where(solution)[0]): 362
# ic| iteration: 293
#     valid(solution): np.True_
#     cost(solution): np.float64(1551167.6637261473)
#     len(np.where(solution)[0]): 362
# ic| iteration: 294
#     valid(solution): np.True_
#     cost(solution): np.float64(1546970.6357427905)
#     len(np.where(solution)[0]): 361
# ic| iteration: 295
#     valid(solution): np.True_
#     cost(solution): np.float64(1542733.669677867)
#     len(np.where(solution)[0]): 360
# ic| iteration: 296
#     valid(solution): np.True_
#     cost(solution): np.float64(1542733.669677867)
#     len(np.where(solution)[0]): 360
# ic| iteration: 297
#     valid(solution): np.True_
#     cost(solution): np.float64(1538282.3413659967)
#     len(np.where(solution)[0]): 359
# ic| iteration: 298
#     valid(solution): np.True_
#     cost(solution): np.float64(1533995.9927611896)
#     len(np.where(solution)[0]): 358
# ic| iteration: 299
#     valid(solution): np.True_
#     cost(solution): np.float64(1533995.9927611896)
#     len(np.where(solution)[0]): 358
# ic| iteration: 300
#     valid(solution): np.True_
#     cost(solution): np.float64(1533995.9927611896)
#     len(np.where(solution)[0]): 358
# ic| iteration: 301
#     valid(solution): np.True_
#     cost(solution): np.float64(1533995.9927611896)
#     len(np.where(solution)[0]): 358
# ic| iteration: 302
#     valid(solution): np.True_
#     cost(solution): np.float64(1529733.1661389521)
#     len(np.where(solution)[0]): 357
# ic| iteration: 303
#     valid(solution): np.True_
#     cost(solution): np.float64(1529733.1661389521)
#     len(np.where(solution)[0]): 357
# ic| iteration: 304
#     valid(solution): np.True_
#     cost(solution): np.float64(1529733.1661389521)
#     len(np.where(solution)[0]): 357
# ic| iteration: 305
#     valid(solution): np.True_
#     cost(solution): np.float64(1525338.4660029719)
#     len(np.where(solution)[0]): 356
# ic| iteration: 306
#     valid(solution): np.True_
#     cost(solution): np.float64(1525338.4660029719)
#     len(np.where(solution)[0]): 356
# ic| iteration: 307
#     valid(solution): np.True_
#     cost(solution): np.float64(1525338.4660029719)
#     len(np.where(solution)[0]): 356
# ic| iteration: 308
#     valid(solution): np.True_
#     cost(solution): np.float64(1525338.4660029719)
#     len(np.where(solution)[0]): 356
# ic| iteration: 309
#     valid(solution): np.True_
#     cost(solution): np.float64(1525338.4660029719)
#     len(np.where(solution)[0]): 356
# ic| iteration: 310
#     valid(solution): np.True_
#     cost(solution): np.float64(1525338.4660029719)
#     len(np.where(solution)[0]): 356
# ic| iteration: 311
#     valid(solution): np.True_
#     cost(solution): np.float64(1525338.4660029719)
#     len(np.where(solution)[0]): 356
# ic| iteration: 312
#     valid(solution): np.True_
#     cost(solution): np.float64(1521047.4115911054)
#     len(np.where(solution)[0]): 355
# ic| iteration: 313
#     valid(solution): np.True_
#     cost(solution): np.float64(1516784.5849688677)
#     len(np.where(solution)[0]): 354
# ic| iteration: 314
#     valid(solution): np.True_
#     cost(solution): np.float64(1512491.1774774967)
#     len(np.where(solution)[0]): 353
# ic| iteration: 315
#     valid(solution): np.True_
#     cost(solution): np.float64(1508054.0123833623)
#     len(np.where(solution)[0]): 352
# ic| iteration: 316
#     valid(solution): np.True_
#     cost(solution): np.float64(1508054.0123833623)
#     len(np.where(solution)[0]): 352
# ic| iteration: 317
#     valid(solution): np.True_
#     cost(solution): np.float64(1508054.0123833623)
#     len(np.where(solution)[0]): 352
# ic| iteration: 318
#     valid(solution): np.True_
#     cost(solution): np.float64(1508054.0123833623)
#     len(np.where(solution)[0]): 352
# ic| iteration: 319
#     valid(solution): np.True_
#     cost(solution): np.float64(1508054.0123833623)
#     len(np.where(solution)[0]): 352
# ic| iteration: 320
#     valid(solution): np.True_
#     cost(solution): np.float64(1508054.0123833623)
#     len(np.where(solution)[0]): 352
# ic| iteration: 321
#     valid(solution): np.True_
#     cost(solution): np.float64(1508054.0123833623)
#     len(np.where(solution)[0]): 352
# ic| iteration: 322
#     valid(solution): np.True_
#     cost(solution): np.float64(1508054.0123833623)
#     len(np.where(solution)[0]): 352
# ic| iteration: 323
#     valid(solution): np.True_
#     cost(solution): np.float64(1503788.834092696)
#     len(np.where(solution)[0]): 351
# ic| iteration: 324
#     valid(solution): np.True_
#     cost(solution): np.float64(1499490.7200906281)
#     len(np.where(solution)[0]): 350
# ic| iteration: 325
#     valid(solution): np.True_
#     cost(solution): np.float64(1499490.7200906281)
#     len(np.where(solution)[0]): 350
# ic| iteration: 326
#     valid(solution): np.True_
#     cost(solution): np.float64(1499490.7200906281)
#     len(np.where(solution)[0]): 350
# ic| iteration: 327
#     valid(solution): np.True_
#     cost(solution): np.float64(1495227.8934683907)
#     len(np.where(solution)[0]): 349
# ic| iteration: 328
#     valid(solution): np.True_
#     cost(solution): np.float64(1490870.9086823463)
#     len(np.where(solution)[0]): 348
# ic| iteration: 329
#     valid(solution): np.True_
#     cost(solution): np.float64(1490870.9086823463)
#     len(np.where(solution)[0]): 348
# ic| iteration: 330
#     valid(solution): np.True_
#     cost(solution): np.float64(1486535.125761461)
#     len(np.where(solution)[0]): 347
# ic| iteration: 331
#     valid(solution): np.True_
#     cost(solution): np.float64(1486535.125761461)
#     len(np.where(solution)[0]): 347
# ic| iteration: 332
#     valid(solution): np.True_
#     cost(solution): np.float64(1486535.125761461)
#     len(np.where(solution)[0]): 347
# ic| iteration: 333
#     valid(solution): np.True_
#     cost(solution): np.float64(1486535.125761461)
#     len(np.where(solution)[0]): 347
# ic| iteration: 334
#     valid(solution): np.True_
#     cost(solution): np.float64(1486535.125761461)
#     len(np.where(solution)[0]): 347
# ic| iteration: 335
#     valid(solution): np.True_
#     cost(solution): np.float64(1486535.125761461)
#     len(np.where(solution)[0]): 347
# ic| iteration: 336
#     valid(solution): np.True_
#     cost(solution): np.float64(1486535.125761461)
#     len(np.where(solution)[0]): 347
# ic| iteration: 337
#     valid(solution): np.True_
#     cost(solution): np.float64(1486535.125761461)
#     len(np.where(solution)[0]): 347
# ic| iteration: 338
#     valid(solution): np.True_
#     cost(solution): np.float64(1486535.125761461)
#     len(np.where(solution)[0]): 347
# ic| iteration: 339
#     valid(solution): np.True_
#     cost(solution): np.float64(1486535.125761461)
#     len(np.where(solution)[0]): 347
# ic| iteration: 340
#     valid(solution): np.True_
#     cost(solution): np.float64(1482269.9474707947)
#     len(np.where(solution)[0]): 346
# ic| iteration: 341
#     valid(solution): np.True_
#     cost(solution): np.float64(1482269.9474707947)
#     len(np.where(solution)[0]): 346
# ic| iteration: 342
#     valid(solution): np.True_
#     cost(solution): np.float64(1482269.9474707947)
#     len(np.where(solution)[0]): 346
# ic| iteration: 343
#     valid(solution): np.True_
#     cost(solution): np.float64(1482269.9474707947)
#     len(np.where(solution)[0]): 346
# ic| iteration: 344
#     valid(solution): np.True_
#     cost(solution): np.float64(1482269.9474707947)
#     len(np.where(solution)[0]): 346
# ic| iteration: 345
#     valid(solution): np.True_
#     cost(solution): np.float64(1482269.9474707947)
#     len(np.where(solution)[0]): 346
# ic| iteration: 346
#     valid(solution): np.True_
#     cost(solution): np.float64(1482269.9474707947)
#     len(np.where(solution)[0]): 346
# ic| iteration: 347
#     valid(solution): np.True_
#     cost(solution): np.float64(1477981.246021134)
#     len(np.where(solution)[0]): 345
# ic| iteration: 348
#     valid(solution): np.True_
#     cost(solution): np.float64(1473741.929587996)
#     len(np.where(solution)[0]): 344
# ic| iteration: 349
#     valid(solution): np.True_
#     cost(solution): np.float64(1473741.929587996)
#     len(np.where(solution)[0]): 344
# ic| iteration: 350
#     valid(solution): np.True_
#     cost(solution): np.float64(1469373.161931003)
#     len(np.where(solution)[0]): 343
# ic| iteration: 351
#     valid(solution): np.True_
#     cost(solution): np.float64(1465020.8894827822)
#     len(np.where(solution)[0]): 342
# ic| iteration: 352
#     valid(solution): np.True_
#     cost(solution): np.float64(1465020.8894827822)
#     len(np.where(solution)[0]): 342
# ic| iteration: 353
#     valid(solution): np.True_
#     cost(solution): np.float64(1465020.8894827822)
#     len(np.where(solution)[0]): 342
# ic| iteration: 354
#     valid(solution): np.True_
# ...
#     len(np.where(solution)[0]): 195
# ic| iteration: 882
#     valid(solution): np.True_
#     cost(solution): np.float64(834776.445587544)
#     len(np.where(solution)[0]): 195
# ic| iteration: 883
#     valid(solution): np.True_
#     cost(solution): np.float64(834776.445587544)
#     len(np.where(solution)[0]): 195
# ic| iteration: 884
#     valid(solution): np.True_
#     cost(solution): np.float64(834776.445587544)
#     len(np.where(solution)[0]): 195
# ic| iteration: 885
#     valid(solution): np.True_
#     cost(solution): np.float64(834776.445587544)
#     len(np.where(solution)[0]): 195
# ic| iteration: 886
#     valid(solution): np.True_
#     cost(solution): np.float64(834776.445587544)
#     len(np.where(solution)[0]): 195
# ic| iteration: 887
#     valid(solution): np.True_
#     cost(solution): np.float64(834776.445587544)
#     len(np.where(solution)[0]): 195
# ic| iteration: 888
#     valid(solution): np.True_
#     cost(solution): np.float64(830433.5964231893)
#     len(np.where(solution)[0]): 194
# ic| iteration: 889
#     valid(solution): np.True_
#     cost(solution): np.float64(830433.5964231893)
#     len(np.where(solution)[0]): 194
# ic| iteration: 890
#     valid(solution): np.True_
#     cost(solution): np.float64(830433.5964231893)
#     len(np.where(solution)[0]): 194
# ic| iteration: 891
#     valid(solution): np.True_
#     cost(solution): np.float64(830433.5964231893)
#     len(np.where(solution)[0]): 194
# ic| iteration: 892
#     valid(solution): np.True_
#     cost(solution): np.float64(830433.5964231893)
#     len(np.where(solution)[0]): 194
# ic| iteration: 893
#     valid(solution): np.True_
#     cost(solution): np.float64(830433.5964231893)
#     len(np.where(solution)[0]): 194
# ic| iteration: 894
#     valid(solution): np.True_
#     cost(solution): np.float64(830433.5964231893)
#     len(np.where(solution)[0]): 194
# ic| iteration: 895
#     valid(solution): np.True_
#     cost(solution): np.float64(830433.5964231893)
#     len(np.where(solution)[0]): 194
# ic| iteration: 896
#     valid(solution): np.True_
#     cost(solution): np.float64(830433.5964231893)
#     len(np.where(solution)[0]): 194
# ic| iteration: 897
#     valid(solution): np.True_
#     cost(solution): np.float64(826253.0035141024)
#     len(np.where(solution)[0]): 193
# ic| iteration: 898
#     valid(solution): np.True_
#     cost(solution): np.float64(826253.0035141024)
#     len(np.where(solution)[0]): 193
# ic| iteration: 899
#     valid(solution): np.True_
#     cost(solution): np.float64(826253.0035141024)
#     len(np.where(solution)[0]): 193
# ic| iteration: 900
#     valid(solution): np.True_
#     cost(solution): np.float64(826253.0035141024)
#     len(np.where(solution)[0]): 193
# ic| iteration: 901
#     valid(solution): np.True_
#     cost(solution): np.float64(826253.0035141024)
#     len(np.where(solution)[0]): 193
# ic| iteration: 902
#     valid(solution): np.True_
#     cost(solution): np.float64(826253.0035141024)
#     len(np.where(solution)[0]): 193
# ic| iteration: 903
#     valid(solution): np.True_
#     cost(solution): np.float64(826253.0035141024)
#     len(np.where(solution)[0]): 193
# ic| iteration: 904
#     valid(solution): np.True_
#     cost(solution): np.float64(821980.7695110755)
#     len(np.where(solution)[0]): 192
# ic| iteration: 905
#     valid(solution): np.True_
#     cost(solution): np.float64(817512.9122665601)
#     len(np.where(solution)[0]): 191
# ic| iteration: 906
#     valid(solution): np.True_
#     cost(solution): np.float64(817512.9122665601)
#     len(np.where(solution)[0]): 191
# ic| iteration: 907
#     valid(solution): np.True_
#     cost(solution): np.float64(817512.9122665601)
#     len(np.where(solution)[0]): 191
# ic| iteration: 908
#     valid(solution): np.True_
#     cost(solution): np.float64(817512.9122665601)
#     len(np.where(solution)[0]): 191
# ic| iteration: 909
#     valid(solution): np.True_
#     cost(solution): np.float64(813219.5047751891)
#     len(np.where(solution)[0]): 190
# ic| iteration: 910
#     valid(solution): np.True_
#     cost(solution): np.float64(813219.5047751891)
#     len(np.where(solution)[0]): 190
# ic| iteration: 911
#     valid(solution): np.True_
#     cost(solution): np.float64(813219.5047751891)
#     len(np.where(solution)[0]): 190
# ic| iteration: 912
#     valid(solution): np.True_
#     cost(solution): np.float64(813219.5047751891)
#     len(np.where(solution)[0]): 190
# ic| iteration: 913
#     valid(solution): np.True_
#     cost(solution): np.float64(813219.5047751891)
#     len(np.where(solution)[0]): 190
# ic| iteration: 914
#     valid(solution): np.True_
#     cost(solution): np.float64(813219.5047751891)
#     len(np.where(solution)[0]): 190
# ic| iteration: 915
#     valid(solution): np.True_
#     cost(solution): np.float64(813219.5047751891)
#     len(np.where(solution)[0]): 190
# ic| iteration: 916
#     valid(solution): np.True_
#     cost(solution): np.float64(813219.5047751891)
#     len(np.where(solution)[0]): 190
# ic| iteration: 917
#     valid(solution): np.True_
#     cost(solution): np.float64(813219.5047751891)
#     len(np.where(solution)[0]): 190
# ic| iteration: 918
#     valid(solution): np.True_
#     cost(solution): np.float64(813219.5047751891)
#     len(np.where(solution)[0]): 190
# ic| iteration: 919
#     valid(solution): np.True_
#     cost(solution): np.float64(813219.5047751891)
#     len(np.where(solution)[0]): 190
# ic| iteration: 920
#     valid(solution): np.True_
#     cost(solution): np.float64(813219.5047751891)
#     len(np.where(solution)[0]): 190
# ic| iteration: 921
#     valid(solution): np.True_
#     cost(solution): np.float64(808855.4506137003)
#     len(np.where(solution)[0]): 189
# ic| iteration: 922
#     valid(solution): np.True_
#     cost(solution): np.float64(804653.7258190124)
#     len(np.where(solution)[0]): 188
# ic| iteration: 923
#     valid(solution): np.True_
#     cost(solution): np.float64(800423.8101473793)
#     len(np.where(solution)[0]): 187
# ic| iteration: 924
#     valid(solution): np.True_
#     cost(solution): np.float64(796205.6427568194)
#     len(np.where(solution)[0]): 186
# ic| iteration: 925
#     valid(solution): np.True_
#     cost(solution): np.float64(796205.6427568194)
#     len(np.where(solution)[0]): 186
# ic| iteration: 926
#     valid(solution): np.True_
#     cost(solution): np.float64(791959.2745084385)
#     len(np.where(solution)[0]): 185
# ic| iteration: 927
#     valid(solution): np.True_
#     cost(solution): np.float64(791959.2745084385)
#     len(np.where(solution)[0]): 185
# ic| iteration: 928
#     valid(solution): np.True_
#     cost(solution): np.float64(791959.2745084385)
#     len(np.where(solution)[0]): 185
# ic| iteration: 929
#     valid(solution): np.True_
#     cost(solution): np.float64(791959.2745084385)
#     len(np.where(solution)[0]): 185
# ic| iteration: 930
#     valid(solution): np.True_
#     cost(solution): np.float64(791959.2745084385)
#     len(np.where(solution)[0]): 185
# ic| iteration: 931
#     valid(solution): np.True_
#     cost(solution): np.float64(791959.2745084385)
#     len(np.where(solution)[0]): 185
# ic| iteration: 932
#     valid(solution): np.True_
#     cost(solution): np.float64(791959.2745084385)
#     len(np.where(solution)[0]): 185
# ic| iteration: 933
#     valid(solution): np.True_
#     cost(solution): np.float64(791959.2745084385)
#     len(np.where(solution)[0]): 185
# ic| iteration: 934
#     valid(solution): np.True_
#     cost(solution): np.float64(787752.8524250768)
#     len(np.where(solution)[0]): 184
# ic| iteration: 935
#     valid(solution): np.True_
#     cost(solution): np.float64(783511.1855052554)
#     len(np.where(solution)[0]): 183
# ic| iteration: 936
#     valid(solution): np.True_
#     cost(solution): np.float64(783511.1855052554)
#     len(np.where(solution)[0]): 183
# ic| iteration: 937
#     valid(solution): np.True_
#     cost(solution): np.float64(783511.1855052554)
#     len(np.where(solution)[0]): 183
# ic| iteration: 938
#     valid(solution): np.True_
#     cost(solution): np.float64(783511.1855052554)
#     len(np.where(solution)[0]): 183
# ic| iteration: 939
#     valid(solution): np.True_
#     cost(solution): np.float64(783511.1855052554)
#     len(np.where(solution)[0]): 183
# ic| iteration: 940
#     valid(solution): np.True_
#     cost(solution): np.float64(783511.1855052554)
#     len(np.where(solution)[0]): 183
# ic| iteration: 941
#     valid(solution): np.True_
#     cost(solution): np.float64(783511.1855052554)
#     len(np.where(solution)[0]): 183
# ic| iteration: 942
#     valid(solution): np.True_
#     cost(solution): np.float64(783511.1855052554)
#     len(np.where(solution)[0]): 183
# ic| iteration: 943
#     valid(solution): np.True_
#     cost(solution): np.float64(783511.1855052554)
#     len(np.where(solution)[0]): 183
# ic| iteration: 944
#     valid(solution): np.True_
#     cost(solution): np.float64(783511.1855052554)
#     len(np.where(solution)[0]): 183
# ic| iteration: 945
#     valid(solution): np.True_
#     cost(solution): np.float64(783511.1855052554)
#     len(np.where(solution)[0]): 183
# ic| iteration: 946
#     valid(solution): np.True_
#     cost(solution): np.float64(783511.1855052554)
#     len(np.where(solution)[0]): 183
# ic| iteration: 947
#     valid(solution): np.True_
#     cost(solution): np.float64(783511.1855052554)
#     len(np.where(solution)[0]): 183
# ic| iteration: 948
#     valid(solution): np.True_
#     cost(solution): np.float64(783511.1855052554)
#     len(np.where(solution)[0]): 183
# ic| iteration: 949
#     valid(solution): np.True_
#     cost(solution): np.float64(783511.1855052554)
#     len(np.where(solution)[0]): 183
# ic| iteration: 950
#     valid(solution): np.True_
#     cost(solution): np.float64(783511.1855052554)
#     len(np.where(solution)[0]): 183
# ic| iteration: 951
#     valid(solution): np.True_
#     cost(solution): np.float64(779264.8172568746)
#     len(np.where(solution)[0]): 182
# ic| iteration: 952
#     valid(solution): np.True_
#     cost(solution): np.float64(774936.0995326855)
#     len(np.where(solution)[0]): 181
# ic| iteration: 953
#     valid(solution): np.True_
#     cost(solution): np.float64(774936.0995326855)
#     len(np.where(solution)[0]): 181
# ic| iteration: 954
#     valid(solution): np.True_
#     cost(solution): np.float64(774936.0995326855)
#     len(np.where(solution)[0]): 181
# ic| iteration: 955
#     valid(solution): np.True_
#     cost(solution): np.float64(774936.0995326855)
#     len(np.where(solution)[0]): 181
# ic| iteration: 956
#     valid(solution): np.True_
#     cost(solution): np.float64(774936.0995326855)
#     len(np.where(solution)[0]): 181
# ic| iteration: 957
#     valid(solution): np.True_
#     cost(solution): np.float64(774936.0995326855)
#     len(np.where(solution)[0]): 181
# ic| iteration: 958
#     valid(solution): np.True_
#     cost(solution): np.float64(774936.0995326855)
#     len(np.where(solution)[0]): 181
# ic| iteration: 959
#     valid(solution): np.True_
#     cost(solution): np.float64(774936.0995326855)
#     len(np.where(solution)[0]): 181
# ic| iteration: 960
#     valid(solution): np.True_
#     cost(solution): np.float64(774936.0995326855)
#     len(np.where(solution)[0]): 181
# ic| iteration: 961
#     valid(solution): np.True_
#     cost(solution): np.float64(774936.0995326855)
#     len(np.where(solution)[0]): 181
# ic| iteration: 962
#     valid(solution): np.True_
#     cost(solution): np.float64(774936.0995326855)
#     len(np.where(solution)[0]): 181
# ic| iteration: 963
#     valid(solution): np.True_
#     cost(solution): np.float64(770553.1886166681)
#     len(np.where(solution)[0]): 180
# ic| iteration: 964
#     valid(solution): np.True_
#     cost(solution): np.float64(770553.1886166681)
#     len(np.where(solution)[0]): 180
# ic| iteration: 965
#     valid(solution): np.True_
#     cost(solution): np.float64(770553.1886166681)
#     len(np.where(solution)[0]): 180
# ic| iteration: 966
#     valid(solution): np.True_
#     cost(solution): np.float64(766344.4177101022)
#     len(np.where(solution)[0]): 179
# ic| iteration: 967
#     valid(solution): np.True_
#     cost(solution): np.float64(766344.4177101022)
#     len(np.where(solution)[0]): 179
# ic| iteration: 968
#     valid(solution): np.True_
#     cost(solution): np.float64(766344.4177101022)
#     len(np.where(solution)[0]): 179
# ic| iteration: 969
#     valid(solution): np.True_
#     cost(solution): np.float64(766344.4177101022)
#     len(np.where(solution)[0]): 179
# ic| iteration: 970
#     valid(solution): np.True_
#     cost(solution): np.float64(766344.4177101022)
#     len(np.where(solution)[0]): 179
# ic| iteration: 971
#     valid(solution): np.True_
#     cost(solution): np.float64(766344.4177101022)
#     len(np.where(solution)[0]): 179
# ic| iteration: 972
#     valid(solution): np.True_
#     cost(solution): np.float64(766344.4177101022)
#     len(np.where(solution)[0]): 179
# ic| iteration: 973
#     valid(solution): np.True_
#     cost(solution): np.float64(762142.6929154141)
#     len(np.where(solution)[0]): 178
# ic| iteration: 974
#     valid(solution): np.True_
#     cost(solution): np.float64(757832.8105875459)
#     len(np.where(solution)[0]): 177
# ic| iteration: 975
#     valid(solution): np.True_
#     cost(solution): np.float64(757832.8105875459)
#     len(np.where(solution)[0]): 177
# ic| iteration: 976
#     valid(solution): np.True_
#     cost(solution): np.float64(757832.8105875459)
#     len(np.where(solution)[0]): 177
# ic| iteration: 977
#     valid(solution): np.True_
#     cost(solution): np.float64(753551.16732018)
#     len(np.where(solution)[0]): 176
# ic| iteration: 978
#     valid(solution): np.True_
#     cost(solution): np.float64(753551.16732018)
#     len(np.where(solution)[0]): 176
# ic| iteration: 979
#     valid(solution): np.True_
#     cost(solution): np.float64(753551.16732018)
#     len(np.where(solution)[0]): 176
# ic| iteration: 980
#     valid(solution): np.True_
#     cost(solution): np.float64(753551.16732018)
#     len(np.where(solution)[0]): 176
# ic| iteration: 981
#     valid(solution): np.True_
#     cost(solution): np.float64(753551.16732018)
#     len(np.where(solution)[0]): 176
# ic| iteration: 982
#     valid(solution): np.True_
#     cost(solution): np.float64(753551.16732018)
#     len(np.where(solution)[0]): 176
# ic| iteration: 983
#     valid(solution): np.True_
#     cost(solution): np.float64(753551.16732018)
#     len(np.where(solution)[0]): 176
# ic| iteration: 984
#     valid(solution): np.True_
#     cost(solution): np.float64(753551.16732018)
#     len(np.where(solution)[0]): 176
# ic| iteration: 985
#     valid(solution): np.True_
#     cost(solution): np.float64(753551.16732018)
#     len(np.where(solution)[0]): 176
# ic| iteration: 986
#     valid(solution): np.True_
#     cost(solution): np.float64(753551.16732018)
#     len(np.where(solution)[0]): 176
# ic| iteration: 987
#     valid(solution): np.True_
#     cost(solution): np.float64(753551.16732018)
#     len(np.where(solution)[0]): 176
# ic| iteration: 988
#     valid(solution): np.True_
#     cost(solution): np.float64(753551.16732018)
#     len(np.where(solution)[0]): 176
# ic| iteration: 989
#     valid(solution): np.True_
#     cost(solution): np.float64(753551.16732018)
#     len(np.where(solution)[0]): 176
# ic| iteration: 990
#     valid(solution): np.True_
#     cost(solution): np.float64(753551.16732018)
#     len(np.where(solution)[0]): 176
# ic| iteration: 991
#     valid(solution): np.True_
#     cost(solution): np.float64(753551.16732018)
#     len(np.where(solution)[0]): 176
# ic| iteration: 992
#     valid(solution): np.True_
#     cost(solution): np.float64(753551.16732018)
#     len(np.where(solution)[0]): 176
# ic| iteration: 993
#     valid(solution): np.True_
#     cost(solution): np.float64(753551.16732018)
#     len(np.where(solution)[0]): 176
# ic| iteration: 994
#     valid(solution): np.True_
#     cost(solution): np.float64(753551.16732018)
#     len(np.where(solution)[0]): 176
# ic| iteration: 995
#     valid(solution): np.True_
#     cost(solution): np.float64(753551.16732018)
#     len(np.where(solution)[0]): 176
# ic| iteration: 996
#     valid(solution): np.True_
#     cost(solution): np.float64(753551.16732018)
#     len(np.where(solution)[0]): 176
# ic| iteration: 997
#     valid(solution): np.True_
#     cost(solution): np.float64(753551.16732018)
#     len(np.where(solution)[0]): 176
# ic| iteration: 998
#     valid(solution): np.True_
#     cost(solution): np.float64(753551.16732018)
#     len(np.where(solution)[0]): 176
# ic| iteration: 999
#     valid(solution): np.True_
#     cost(solution): np.float64(753551.16732018)
#     len(np.where(solution)[0]): 176
# Best solution (multiple tweak) cost: 753551.16732018

# %% [markdown]
# **Hill Climbing algorithm with multiple tweaks**

# %%
# Hill Climbing algorithm with multiple tweaks 
def hill_climbing(tweak_function, max_iters=1000):
    solution = rng.random(NUM_SETS) < 0.5  # Start with 50% sets selected
    best_fitness = fitness(solution)

    for iteration in range(max_iters):
        new_solution = tweak_function(solution)
        new_fitness = fitness(new_solution)

        if new_fitness > best_fitness:  # If the new solution is better
            solution = new_solution
            best_fitness = new_fitness

        ic(iteration, valid(solution), cost(solution), len(np.where(solution)[0]), best_fitness)

    return solution, best_fitness

# Running the hill climbing algorithm with multiple tweaks
best_solution_multi, best_fitness_multi = hill_climbing(lambda sol: multiple_tweak(sol, prob=0.01), max_iters=1000)
print(f"Best solution (multiple tweak) cost: {-best_fitness_multi}")
# Out:
# ic| iteration: 0
#     valid(solution): np.True_
#     cost(solution): np.float64(2249757.3060013438)
#     len(np.where(solution)[0]): 526
#     best_fitness: np.float64(-2249757.3060013438)
# ic| iteration: 1
#     valid(solution): np.True_
#     cost(solution): np.float64(2249757.3060013438)
#     len(np.where(solution)[0]): 526
#     best_fitness: np.float64(-2249757.3060013438)
# ic| iteration: 2
#     valid(solution): np.True_
#     cost(solution): np.float64(2249757.3060013438)
#     len(np.where(solution)[0]): 526
#     best_fitness: np.float64(-2249757.3060013438)
# ic| iteration: 3
#     valid(solution): np.True_
#     cost(solution): np.float64(2249757.3060013438)
#     len(np.where(solution)[0]): 526
#     best_fitness: np.float64(-2249757.3060013438)
# ic| iteration: 4
#     valid(solution): np.True_
#     cost(solution): np.float64(2232592.9262890485)
#     len(np.where(solution)[0]): 522
#     best_fitness: np.float64(-2232592.9262890485)
# ic| iteration: 5
#     valid(solution): np.True_
#     cost(solution): np.float64(2224147.053985966)
#     len(np.where(solution)[0]): 520
#     best_fitness: np.float64(-2224147.053985966)
# ic| iteration: 6
#     valid(solution): np.True_
#     cost(solution): np.float64(2223992.902778201)
#     len(np.where(solution)[0]): 520
#     best_fitness: np.float64(-2223992.902778201)
# ic| iteration: 7
#     valid(solution): np.True_
#     cost(solution): np.float64(2207051.8939792416)
#     len(np.where(solution)[0]): 516
#     best_fitness: np.float64(-2207051.8939792416)
# ic| iteration: 8
#     valid(solution): np.True_
#     cost(solution): np.float64(2206776.759773285)
#     len(np.where(solution)[0]): 516
#     best_fitness: np.float64(-2206776.759773285)
# ic| iteration: 9
#     valid(solution): np.True_
#     cost(solution): np.float64(2206776.759773285)
#     len(np.where(solution)[0]): 516
#     best_fitness: np.float64(-2206776.759773285)
# ic| iteration: 10
#     valid(solution): np.True_
#     cost(solution): np.float64(2202591.3779042615)
#     len(np.where(solution)[0]): 515
#     best_fitness: np.float64(-2202591.3779042615)
# ic| iteration: 11
#     valid(solution): np.True_
#     cost(solution): np.float64(2202591.3779042615)
#     len(np.where(solution)[0]): 515
#     best_fitness: np.float64(-2202591.3779042615)
# ic| iteration: 12
#     valid(solution): np.True_
#     cost(solution): np.float64(2180798.9419636624)
#     len(np.where(solution)[0]): 510
#     best_fitness: np.float64(-2180798.9419636624)
# ic| iteration: 13
#     valid(solution): np.True_
#     cost(solution): np.float64(2180798.9419636624)
#     len(np.where(solution)[0]): 510
#     best_fitness: np.float64(-2180798.9419636624)
# ic| iteration: 14
#     valid(solution): np.True_
#     cost(solution): np.float64(2180798.9419636624)
#     len(np.where(solution)[0]): 510
#     best_fitness: np.float64(-2180798.9419636624)
# ic| iteration: 15
#     valid(solution): np.True_
#     cost(solution): np.float64(2180798.9419636624)
#     len(np.where(solution)[0]): 510
#     best_fitness: np.float64(-2180798.9419636624)
# ic| iteration: 16
#     valid(solution): np.True_
#     cost(solution): np.float64(2180674.2977639693)
#     len(np.where(solution)[0]): 510
#     best_fitness: np.float64(-2180674.2977639693)
# ic| iteration: 17
#     valid(solution): np.True_
#     cost(solution): np.float64(2180674.2977639693)
#     len(np.where(solution)[0]): 510
#     best_fitness: np.float64(-2180674.2977639693)
# ic| iteration: 18
#     valid(solution): np.True_
#     cost(solution): np.float64(2180674.2977639693)
#     len(np.where(solution)[0]): 510
#     best_fitness: np.float64(-2180674.2977639693)
# ic| iteration: 19
#     valid(solution): np.True_
#     cost(solution): np.float64(2180674.2977639693)
#     len(np.where(solution)[0]): 510
#     best_fitness: np.float64(-2180674.2977639693)
# ic| iteration: 20
#     valid(solution): np.True_
#     cost(solution): np.float64(2177004.857813404)
#     len(np.where(solution)[0]): 509
#     best_fitness: np.float64(-2177004.857813404)
# ic| iteration: 21
#     valid(solution): np.True_
#     cost(solution): np.float64(2164200.4893502276)
#     len(np.where(solution)[0]): 506
#     best_fitness: np.float64(-2164200.4893502276)
# ic| iteration: 22
#     valid(solution): np.True_
#     cost(solution): np.float64(2164200.4893502276)
#     len(np.where(solution)[0]): 506
#     best_fitness: np.float64(-2164200.4893502276)
# ic| iteration: 23
#     valid(solution): np.True_
#     cost(solution): np.float64(2151498.896259529)
#     len(np.where(solution)[0]): 503
#     best_fitness: np.float64(-2151498.896259529)
# ic| iteration: 24
#     valid(solution): np.True_
#     cost(solution): np.float64(2151498.896259529)
#     len(np.where(solution)[0]): 503
#     best_fitness: np.float64(-2151498.896259529)
# ic| iteration: 25
#     valid(solution): np.True_
#     cost(solution): np.float64(2151498.896259529)
#     len(np.where(solution)[0]): 503
#     best_fitness: np.float64(-2151498.896259529)
# ic| iteration: 26
#     valid(solution): np.True_
#     cost(solution): np.float64(2138549.7404927704)
#     len(np.where(solution)[0]): 500
#     best_fitness: np.float64(-2138549.7404927704)
# ic| iteration: 27
#     valid(solution): np.True_
#     cost(solution): np.float64(2138292.4886237346)
#     len(np.where(solution)[0]): 500
#     best_fitness: np.float64(-2138292.4886237346)
# ic| iteration: 28
#     valid(solution): np.True_
#     cost(solution): np.float64(2138292.4886237346)
#     len(np.where(solution)[0]): 500
#     best_fitness: np.float64(-2138292.4886237346)
# ic| iteration: 29
#     valid(solution): np.True_
#     cost(solution): np.float64(2125440.2033683183)
#     len(np.where(solution)[0]): 497
#     best_fitness: np.float64(-2125440.2033683183)
# ic| iteration: 30
#     valid(solution): np.True_
#     cost(solution): np.float64(2113020.3065698408)
#     len(np.where(solution)[0]): 494
#     best_fitness: np.float64(-2113020.3065698408)
# ic| iteration: 31
#     valid(solution): np.True_
#     cost(solution): np.float64(2108740.730365364)
#     len(np.where(solution)[0]): 493
#     best_fitness: np.float64(-2108740.730365364)
# ic| iteration: 32
#     valid(solution): np.True_
#     cost(solution): np.float64(2108740.730365364)
#     len(np.where(solution)[0]): 493
#     best_fitness: np.float64(-2108740.730365364)
# ic| iteration: 33
#     valid(solution): np.True_
#     cost(solution): np.float64(2108740.730365364)
#     len(np.where(solution)[0]): 493
#     best_fitness: np.float64(-2108740.730365364)
# ic| iteration: 34
#     valid(solution): np.True_
#     cost(solution): np.float64(2099986.980119737)
#     len(np.where(solution)[0]): 491
#     best_fitness: np.float64(-2099986.980119737)
# ic| iteration: 35
#     valid(solution): np.True_
#     cost(solution): np.float64(2099986.980119737)
#     len(np.where(solution)[0]): 491
#     best_fitness: np.float64(-2099986.980119737)
# ic| iteration: 36
#     valid(solution): np.True_
#     cost(solution): np.float64(2095780.6004949883)
#     len(np.where(solution)[0]): 490
#     best_fitness: np.float64(-2095780.6004949883)
# ic| iteration: 37
#     valid(solution): np.True_
#     cost(solution): np.float64(2095780.6004949883)
#     len(np.where(solution)[0]): 490
#     best_fitness: np.float64(-2095780.6004949883)
# ic| iteration: 38
#     valid(solution): np.True_
#     cost(solution): np.float64(2095721.8468556353)
#     len(np.where(solution)[0]): 490
#     best_fitness: np.float64(-2095721.8468556353)
# ic| iteration: 39
#     valid(solution): np.True_
#     cost(solution): np.float64(2095721.8468556353)
#     len(np.where(solution)[0]): 490
#     best_fitness: np.float64(-2095721.8468556353)
# ic| iteration: 40
#     valid(solution): np.True_
#     cost(solution): np.float64(2091511.00088436)
#     len(np.where(solution)[0]): 489
#     best_fitness: np.float64(-2091511.00088436)
# ic| iteration: 41
#     valid(solution): np.True_
#     cost(solution): np.float64(2091511.00088436)
#     len(np.where(solution)[0]): 489
#     best_fitness: np.float64(-2091511.00088436)
# ic| iteration: 42
#     valid(solution): np.True_
#     cost(solution): np.float64(2091511.00088436)
#     len(np.where(solution)[0]): 489
#     best_fitness: np.float64(-2091511.00088436)
# ic| iteration: 43
#     valid(solution): np.True_
#     cost(solution): np.float64(2087287.9955259282)
#     len(np.where(solution)[0]): 488
#     best_fitness: np.float64(-2087287.9955259282)
# ic| iteration: 44
#     valid(solution): np.True_
#     cost(solution): np.float64(2087287.9955259282)
#     len(np.where(solution)[0]): 488
#     best_fitness: np.float64(-2087287.9955259282)
# ic| iteration: 45
#     valid(solution): np.True_
#     cost(solution): np.float64(2082923.3820723193)
#     len(np.where(solution)[0]): 487
#     best_fitness: np.float64(-2082923.3820723193)
# ic| iteration: 46
#     valid(solution): np.True_
#     cost(solution): np.float64(2082923.3820723193)
#     len(np.where(solution)[0]): 487
#     best_fitness: np.float64(-2082923.3820723193)
# ic| iteration: 47
#     valid(solution): np.True_
#     cost(solution): np.float64(2082923.3820723193)
#     len(np.where(solution)[0]): 487
#     best_fitness: np.float64(-2082923.3820723193)
# ic| iteration: 48
#     valid(solution): np.True_
#     cost(solution): np.float64(2082923.3820723193)
#     len(np.where(solution)[0]): 487
#     best_fitness: np.float64(-2082923.3820723193)
# ic| iteration: 49
#     valid(solution): np.True_
#     cost(solution): np.float64(2082742.237029456)
#     len(np.where(solution)[0]): 487
#     best_fitness: np.float64(-2082742.237029456)
# ic| iteration: 50
#     valid(solution): np.True_
#     cost(solution): np.float64(2082742.237029456)
#     len(np.where(solution)[0]): 487
#     best_fitness: np.float64(-2082742.237029456)
# ic| iteration: 51
#     valid(solution): np.True_
#     cost(solution): np.float64(2074573.62374306)
#     len(np.where(solution)[0]): 485
#     best_fitness: np.float64(-2074573.62374306)
# ic| iteration: 52
#     valid(solution): np.True_
#     cost(solution): np.float64(2074573.62374306)
#     len(np.where(solution)[0]): 485
#     best_fitness: np.float64(-2074573.62374306)
# ic| iteration: 53
#     valid(solution): np.True_
#     cost(solution): np.float64(2074573.62374306)
#     len(np.where(solution)[0]): 485
#     best_fitness: np.float64(-2074573.62374306)
# ic| iteration: 54
#     valid(solution): np.True_
#     cost(solution): np.float64(2074573.62374306)
#     len(np.where(solution)[0]): 485
#     best_fitness: np.float64(-2074573.62374306)
# ic| iteration: 55
#     valid(solution): np.True_
#     cost(solution): np.float64(2074573.62374306)
#     len(np.where(solution)[0]): 485
#     best_fitness: np.float64(-2074573.62374306)
# ic| iteration: 56
#     valid(solution): np.True_
#     cost(solution): np.float64(2074573.62374306)
#     len(np.where(solution)[0]): 485
#     best_fitness: np.float64(-2074573.62374306)
# ic| iteration: 57
#     valid(solution): np.True_
#     cost(solution): np.float64(2074573.62374306)
#     len(np.where(solution)[0]): 485
#     best_fitness: np.float64(-2074573.62374306)
# ic| iteration: 58
#     valid(solution): np.True_
#     cost(solution): np.float64(2074573.62374306)
#     len(np.where(solution)[0]): 485
#     best_fitness: np.float64(-2074573.62374306)
# ic| iteration: 59
#     valid(solution): np.True_
#     cost(solution): np.float64(2057096.3521184619)
#     len(np.where(solution)[0]): 481
#     best_fitness: np.float64(-2057096.3521184619)
# ic| iteration: 60
#     valid(solution): np.True_
#     cost(solution): np.float64(2057096.3521184619)
#     len(np.where(solution)[0]): 481
#     best_fitness: np.float64(-2057096.3521184619)
# ic| iteration: 61
#     valid(solution): np.True_
#     cost(solution): np.float64(2053334.3549803195)
#     len(np.where(solution)[0]): 480
#     best_fitness: np.float64(-2053334.3549803195)
# ic| iteration: 62
#     valid(solution): np.True_
#     cost(solution): np.float64(2053334.3549803195)
#     len(np.where(solution)[0]): 480
#     best_fitness: np.float64(-2053334.3549803195)
# ic| iteration: 63
#     valid(solution): np.True_
#     cost(solution): np.float64(2053089.7358434522)
#     len(np.where(solution)[0]): 480
#     best_fitness: np.float64(-2053089.7358434522)
# ic| iteration: 64
#     valid(solution): np.True_
#     cost(solution): np.float64(2053089.7358434522)
#     len(np.where(solution)[0]): 480
#     best_fitness: np.float64(-2053089.7358434522)
# ic| iteration: 65
#     valid(solution): np.True_
#     cost(solution): np.float64(2053089.7358434522)
#     len(np.where(solution)[0]): 480
#     best_fitness: np.float64(-2053089.7358434522)
# ic| iteration: 66
#     valid(solution): np.True_
#     cost(solution): np.float64(2044530.821696546)
#     len(np.where(solution)[0]): 478
#     best_fitness: np.float64(-2044530.821696546)
# ic| iteration: 67
#     valid(solution): np.True_
#     cost(solution): np.float64(2036313.3066654583)
#     len(np.where(solution)[0]): 476
#     best_fitness: np.float64(-2036313.3066654583)
# ic| iteration: 68
#     valid(solution): np.True_
#     cost(solution): np.float64(2031478.0296561124)
#     len(np.where(solution)[0]): 475
#     best_fitness: np.float64(-2031478.0296561124)
# ic| iteration: 69
#     valid(solution): np.True_
#     cost(solution): np.float64(2031478.0296561124)
#     len(np.where(solution)[0]): 475
#     best_fitness: np.float64(-2031478.0296561124)
# ic| iteration: 70
#     valid(solution): np.True_
#     cost(solution): np.float64(2018686.953754363)
#     len(np.where(solution)[0]): 472
#     best_fitness: np.float64(-2018686.953754363)
# ic| iteration: 71
#     valid(solution): np.True_
#     cost(solution): np.float64(2018686.953754363)
#     len(np.where(solution)[0]): 472
#     best_fitness: np.float64(-2018686.953754363)
# ic| iteration: 72
#     valid(solution): np.True_
#     cost(solution): np.float64(2018686.953754363)
#     len(np.where(solution)[0]): 472
#     best_fitness: np.float64(-2018686.953754363)
# ic| iteration: 73
#     valid(solution): np.True_
#     cost(solution): np.float64(2010172.8405733504)
#     len(np.where(solution)[0]): 470
#     best_fitness: np.float64(-2010172.8405733504)
# ic| iteration: 74
#     valid(solution): np.True_
#     cost(solution): np.float64(2010172.8405733504)
#     len(np.where(solution)[0]): 470
#     best_fitness: np.float64(-2010172.8405733504)
# ic| iteration: 75
#     valid(solution): np.True_
#     cost(solution): np.float64(2001696.387705716)
#     len(np.where(solution)[0]): 468
#     best_fitness: np.float64(-2001696.387705716)
# ic| iteration: 76
#     valid(solution): np.True_
#     cost(solution): np.float64(2001696.387705716)
#     len(np.where(solution)[0]): 468
#     best_fitness: np.float64(-2001696.387705716)
# ic| iteration: 77
#     valid(solution): np.True_
#     cost(solution): np.float64(2001696.387705716)
#     len(np.where(solution)[0]): 468
#     best_fitness: np.float64(-2001696.387705716)
# ic| iteration: 78
#     valid(solution): np.True_
#     cost(solution): np.float64(1992422.6816727733)
#     len(np.where(solution)[0]): 466
#     best_fitness: np.float64(-1992422.6816727733)
# ic| iteration: 79
#     valid(solution): np.True_
#     cost(solution): np.float64(1992422.6816727733)
#     len(np.where(solution)[0]): 466
#     best_fitness: np.float64(-1992422.6816727733)
# ic| iteration: 80
#     valid(solution): np.True_
#     cost(solution): np.float64(1992422.6816727733)
#     len(np.where(solution)[0]): 466
#     best_fitness: np.float64(-1992422.6816727733)
# ic| iteration: 81
#     valid(solution): np.True_
#     cost(solution): np.float64(1992422.6816727733)
#     len(np.where(solution)[0]): 466
#     best_fitness: np.float64(-1992422.6816727733)
# ic| iteration: 82
#     valid(solution): np.True_
#     cost(solution): np.float64(1992422.6816727733)
#     len(np.where(solution)[0]): 466
#     best_fitness: np.float64(-1992422.6816727733)
# ic| iteration: 83
#     valid(solution): np.True_
#     cost(solution): np.float64(1992422.6816727733)
#     len(np.where(solution)[0]): 466
#     best_fitness: np.float64(-1992422.6816727733)
# ic| iteration: 84
#     valid(solution): np.True_
#     cost(solution): np.float64(1992422.6816727733)
#     len(np.where(solution)[0]): 466
#     best_fitness: np.float64(-1992422.6816727733)
# ic| iteration: 85
#     valid(solution): np.True_
#     cost(solution): np.float64(1992422.6816727733)
#     len(np.where(solution)[0]): 466
#     best_fitness: np.float64(-1992422.6816727733)
# ic| iteration: 86
#     valid(solution): np.True_
#     cost(solution): np.float64(1992044.1874708538)
#     len(np.where(solution)[0]): 466
#     best_fitness: np.float64(-1992044.1874708538)
# ic| iteration: 87
#     valid(solution): np.True_
#     cost(solution): np.float64(1992044.1874708538)
#     len(np.where(solution)[0]): 466
#     best_fitness: np.float64(-1992044.1874708538)
# ic| iteration: 88
#     valid(solution): np.True_
#     cost(solution): np.float64(1992044.1874708538)
#     len(np.where(solution)[0]): 466
#     best_fitness: np.float64(-1992044.1874708538)
# ic| iteration: 89
#     valid(solution): np.True_
#     cost(solution): np.float64(1992044.1874708538)
#     len(np.where(solution)[0]): 466
#     best_fitness: np.float64(-1992044.1874708538)
# ic| iteration: 90
#     valid(solution): np.True_
#     cost(solution): np.float64(1992044.1874708538)
#     len(np.where(solution)[0]): 466
#     best_fitness: np.float64(-1992044.1874708538)
# ic| iteration: 91
#     valid(solution): np.True_
#     cost(solution): np.float64(1992044.1874708538)
#     len(np.where(solution)[0]): 466
#     best_fitness: np.float64(-1992044.1874708538)
# ic| iteration: 92
#     valid(solution): np.True_
#     cost(solution): np.float64(1975253.0573391514)
#     len(np.where(solution)[0]): 462
#     best_fitness: np.float64(-1975253.0573391514)
# ic| iteration: 93
#     valid(solution): np.True_
#     cost(solution): np.float64(1962567.9097264812)
#     len(np.where(solution)[0]): 459
#     best_fitness: np.float64(-1962567.9097264812)
# ic| iteration: 94
#     valid(solution): np.True_
#     cost(solution): np.float64(1949694.8377286678)
#     len(np.where(solution)[0]): 456
#     best_fitness: np.float64(-1949694.8377286678)
# ic| iteration: 95
#     valid(solution): np.True_
#     cost(solution): np.float64(1949694.8377286678)
#     len(np.where(solution)[0]): 456
#     best_fitness: np.float64(-1949694.8377286678)
# ic| iteration: 96
#     valid(solution): np.True_
#     cost(solution): np.float64(1949694.8377286678)
#     len(np.where(solution)[0]): 456
#     best_fitness: np.float64(-1949694.8377286678)
# ic| iteration: 97
#     valid(solution): np.True_
#     cost(solution): np.float64(1936447.450734572)
#     len(np.where(solution)[0]): 453
#     best_fitness: np.float64(-1936447.450734572)
# ic| iteration: 98
#     valid(solution): np.True_
#     cost(solution): np.float64(1932638.232760443)
#     len(np.where(solution)[0]): 452
#     best_fitness: np.float64(-1932638.232760443)
# ic| iteration: 99
#     valid(solution): np.True_
#     cost(solution): np.float64(1907073.0112336907)
#     len(np.where(solution)[0]): 446
#     best_fitness: np.float64(-1907073.0112336907)
# ic| iteration: 100
#     valid(solution): np.True_
#     cost(solution): np.float64(1907073.0112336907)
#     len(np.where(solution)[0]): 446
#     best_fitness: np.float64(-1907073.0112336907)
# ic| iteration: 101
#     valid(solution): np.True_
#     cost(solution): np.float64(1898326.0847420846)
#     len(np.where(solution)[0]): 444
#     best_fitness: np.float64(-1898326.0847420846)
# ic| iteration: 102
#     valid(solution): np.True_
#     cost(solution): np.float64(1898326.0847420846)
#     len(np.where(solution)[0]): 444
#     best_fitness: np.float64(-1898326.0847420846)
# ic| iteration: 103
#     valid(solution): np.True_
#     cost(solution): np.float64(1894223.1995029533)
#     len(np.where(solution)[0]): 443
#     best_fitness: np.float64(-1894223.1995029533)
# ic| iteration: 104
#     valid(solution): np.True_
#     cost(solution): np.float64(1890273.4197238865)
#     len(np.where(solution)[0]): 442
#     best_fitness: np.float64(-1890273.4197238865)
# ic| iteration: 105
#     valid(solution): np.True_
#     cost(solution): np.float64(1890273.4197238865)
#     len(np.where(solution)[0]): 442
#     best_fitness: np.float64(-1890273.4197238865)
# ic| iteration: 106
#     valid(solution): np.True_
#     cost(solution): np.float64(1889960.649954223)
#     len(np.where(solution)[0]): 442
#     best_fitness: np.float64(-1889960.649954223)
# ic| iteration: 107
#     valid(solution): np.True_
#     cost(solution): np.float64(1889960.649954223)
#     len(np.where(solution)[0]): 442
#     best_fitness: np.float64(-1889960.649954223)
# ic| iteration: 108
#     valid(solution): np.True_
#     cost(solution): np.float64(1889960.649954223)
#     len(np.where(solution)[0]): 442
#     best_fitness: np.float64(-1889960.649954223)
# ic| iteration: 109
#     valid(solution): np.True_
#     cost(solution): np.float64(1889960.649954223)
#     len(np.where(solution)[0]): 442
#     best_fitness: np.float64(-1889960.649954223)
# ic| iteration: 110
#     valid(solution): np.True_
#     cost(solution): np.float64(1889578.693910493)
#     len(np.where(solution)[0]): 442
#     best_fitness: np.float64(-1889578.693910493)
# ic| iteration: 111
#     valid(solution): np.True_
#     cost(solution): np.float64(1889578.693910493)
#     len(np.where(solution)[0]): 442
#     best_fitness: np.float64(-1889578.693910493)
# ic| iteration: 112
#     valid(solution): np.True_
#     cost(solution): np.float64(1876424.8310997142)
#     len(np.where(solution)[0]): 439
#     best_fitness: np.float64(-1876424.8310997142)
# ic| iteration: 113
#     valid(solution): np.True_
#     cost(solution): np.float64(1875947.3264182303)
#     len(np.where(solution)[0]): 439
#     best_fitness: np.float64(-1875947.3264182303)
# ic| iteration: 114
#     valid(solution): np.True_
#     cost(solution): np.float64(1875874.8112659156)
#     len(np.where(solution)[0]): 439
#     best_fitness: np.float64(-1875874.8112659156)
# ic| iteration: 115
#     valid(solution): np.True_
#     cost(solution): np.float64(1858846.9822696836)
#     len(np.where(solution)[0]): 435
#     best_fitness: np.float64(-1858846.9822696836)
# ic| iteration: 116
#     valid(solution): np.True_
#     cost(solution): np.float64(1858846.9822696836)
#     len(np.where(solution)[0]): 435
#     best_fitness: np.float64(-1858846.9822696836)
# ic| iteration: 117
#     valid(solution): np.True_
#     cost(solution): np.float64(1858846.9822696836)
#     len(np.where(solution)[0]): 435
#     best_fitness: np.float64(-1858846.9822696836)
# ic| iteration: 118
#     valid(solution): np.True_
#     cost(solution): np.float64(1858846.9822696836)
#     len(np.where(solution)[0]): 435
#     best_fitness: np.float64(-1858846.9822696836)
# ic| iteration: 119
#     valid(solution): np.True_
#     cost(solution): np.float64(1850540.375758138)
#     len(np.where(solution)[0]): 433
#     best_fitness: np.float64(-1850540.375758138)
# ic| iteration: 120
#     valid(solution): np.True_
#     cost(solution): np.float64(1850540.375758138)
#     len(np.where(solution)[0]): 433
#     best_fitness: np.float64(-1850540.375758138)
# ic| iteration: 121
#     valid(solution): np.True_
#     cost(solution): np.float64(1850540.375758138)
#     len(np.where(solution)[0]): 433
#     best_fitness: np.float64(-1850540.375758138)
# ic| iteration: 122
#     valid(solution): np.True_
#     cost(solution): np.float64(1850540.375758138)
#     len(np.where(solution)[0]): 433
#     best_fitness: np.float64(-1850540.375758138)
# ic| iteration: 123
#     valid(solution): np.True_
#     cost(solution): np.float64(1850540.375758138)
#     len(np.where(solution)[0]): 433
#     best_fitness: np.float64(-1850540.375758138)
# ic| iteration: 124
#     valid(solution): np.True_
#     cost(solution): np.float64(1850540.375758138)
#     len(np.where(solution)[0]): 433
#     best_fitness: np.float64(-1850540.375758138)
# ic| iteration: 125
#     valid(solution): np.True_
#     cost(solution): np.float64(1842254.6159640984)
#     len(np.where(solution)[0]): 431
#     best_fitness: np.float64(-1842254.6159640984)
# ic| iteration: 126
#     valid(solution): np.True_
#     cost(solution): np.float64(1842254.6159640984)
#     len(np.where(solution)[0]): 431
#     best_fitness: np.float64(-1842254.6159640984)
# ic| iteration: 127
#     valid(solution): np.True_
#     cost(solution): np.float64(1842254.6159640984)
#     len(np.where(solution)[0]): 431
#     best_fitness: np.float64(-1842254.6159640984)
# ic| iteration: 128
#     valid(solution): np.True_
#     cost(solution): np.float64(1842254.6159640984)
#     len(np.where(solution)[0]): 431
#     best_fitness: np.float64(-1842254.6159640984)
# ic| iteration: 129
#     valid(solution): np.True_
#     cost(solution): np.float64(1842254.6159640984)
#     len(np.where(solution)[0]): 431
#     best_fitness: np.float64(-1842254.6159640984)
# ic| iteration: 130
#     valid(solution): np.True_
#     cost(solution): np.float64(1842254.6159640984)
#     len(np.where(solution)[0]): 431
#     best_fitness: np.float64(-1842254.6159640984)
# ic| iteration: 131
#     valid(solution): np.True_
#     cost(solution): np.float64(1842254.6159640984)
#     len(np.where(solution)[0]): 431
#     best_fitness: np.float64(-1842254.6159640984)
# ic| iteration: 132
#     valid(solution): np.True_
#     cost(solution): np.float64(1842254.6159640984)
#     len(np.where(solution)[0]): 431
#     best_fitness: np.float64(-1842254.6159640984)
# ic| iteration: 133
#     valid(solution): np.True_
#     cost(solution): np.float64(1842254.6159640984)
#     len(np.where(solution)[0]): 431
#     best_fitness: np.float64(-1842254.6159640984)
# ic| iteration: 134
#     valid(solution): np.True_
#     cost(solution): np.float64(1842254.6159640984)
#     len(np.where(solution)[0]): 431
#     best_fitness: np.float64(-1842254.6159640984)
# ic| iteration: 135
#     valid(solution): np.True_
#     cost(solution): np.float64(1834163.8601533864)
#     len(np.where(solution)[0]): 429
#     best_fitness: np.float64(-1834163.8601533864)
# ic| iteration: 136
#     valid(solution): np.True_
#     cost(solution): np.float64(1834163.8601533864)
#     len(np.where(solution)[0]): 429
#     best_fitness: np.float64(-1834163.8601533864)
# ic| iteration: 137
#     valid(solution): np.True_
#     cost(solution): np.float64(1834163.8601533864)
#     len(np.where(solution)[0]): 429
#     best_fitness: np.float64(-1834163.8601533864)
# ic| iteration: 138
#     valid(solution): np.True_
#     cost(solution): np.float64(1834163.8601533864)
#     len(np.where(solution)[0]): 429
#     best_fitness: np.float64(-1834163.8601533864)
# ic| iteration: 139
#     valid(solution): np.True_
#     cost(solution): np.float64(1834163.8601533864)
#     len(np.where(solution)[0]): 429
#     best_fitness: np.float64(-1834163.8601533864)
# ic| iteration: 140
#     valid(solution): np.True_
#     cost(solution): np.float64(1834163.8601533864)
#     len(np.where(solution)[0]): 429
#     best_fitness: np.float64(-1834163.8601533864)
# ic| iteration: 141
#     valid(solution): np.True_
#     cost(solution): np.float64(1834156.403310867)
#     len(np.where(solution)[0]): 429
#     best_fitness: np.float64(-1834156.403310867)
# ic| iteration: 142
#     valid(solution): np.True_
#     cost(solution): np.float64(1834156.403310867)
#     len(np.where(solution)[0]): 429
#     best_fitness: np.float64(-1834156.403310867)
# ic| iteration: 143
#     valid(solution): np.True_
#     cost(solution): np.float64(1834156.403310867)
#     len(np.where(solution)[0]): 429
#     best_fitness: np.float64(-1834156.403310867)
# ic| iteration: 144
#     valid(solution): np.True_
#     cost(solution): np.float64(1834156.403310867)
#     len(np.where(solution)[0]): 429
#     best_fitness: np.float64(-1834156.403310867)
# ic| iteration: 145
#     valid(solution): np.True_
#     cost(solution): np.float64(1830389.9404687562)
#     len(np.where(solution)[0]): 428
#     best_fitness: np.float64(-1830389.9404687562)
# ic| iteration: 146
#     valid(solution): np.True_
#     cost(solution): np.float64(1830389.9404687562)
#     len(np.where(solution)[0]): 428
#     best_fitness: np.float64(-1830389.9404687562)
# ic| iteration: 147
#     valid(solution): np.True_
#     cost(solution): np.float64(1830389.9404687562)
#     len(np.where(solution)[0]): 428
#     best_fitness: np.float64(-1830389.9404687562)
# ic| iteration: 148
#     valid(solution): np.True_
#     cost(solution): np.float64(1830107.6560419567)
#     len(np.where(solution)[0]): 428
#     best_fitness: np.float64(-1830107.6560419567)
# ic| iteration: 149
#     valid(solution): np.True_
#     cost(solution): np.float64(1830107.6560419567)
#     len(np.where(solution)[0]): 428
#     best_fitness: np.float64(-1830107.6560419567)
# ic| iteration: 150
#     valid(solution): np.True_
#     cost(solution): np.float64(1829846.4344322823)
#     len(np.where(solution)[0]): 428
#     best_fitness: np.float64(-1829846.4344322823)
# ic| iteration: 151
#     valid(solution): np.True_
#     cost(solution): np.float64(1829846.4344322823)
#     len(np.where(solution)[0]): 428
#     best_fitness: np.float64(-1829846.4344322823)
# ic| iteration: 152
#     valid(solution): np.True_
#     cost(solution): np.float64(1804615.2849823171)
#     len(np.where(solution)[0]): 422
#     best_fitness: np.float64(-1804615.2849823171)
# ic| iteration: 153
#     valid(solution): np.True_
#     cost(solution): np.float64(1804615.2849823171)
#     len(np.where(solution)[0]): 422
#     best_fitness: np.float64(-1804615.2849823171)
# ic| iteration: 154
#     valid(solution): np.True_
#     cost(solution): np.float64(1796466.4907173258)
#     len(np.where(solution)[0]): 420
#     best_fitness: np.float64(-1796466.4907173258)
# ic| iteration: 155
#     valid(solution): np.True_
#     cost(solution): np.float64(1796466.4907173258)
#     len(np.where(solution)[0]): 420
#     best_fitness: np.float64(-1796466.4907173258)
# ic| iteration: 156
#     valid(solution): np.True_
#     cost(solution): np.float64(1779297.179075046)
#     len(np.where(solution)[0]): 416
#     best_fitness: np.float64(-1779297.179075046)
# ic| iteration: 157
#     valid(solution): np.True_
#     cost(solution): np.float64(1766802.3077355963)
#     len(np.where(solution)[0]): 413
#     best_fitness: np.float64(-1766802.3077355963)
# ic| iteration: 158
#     valid(solution): np.True_
#     cost(solution): np.float64(1762504.0522980404)
#     len(np.where(solution)[0]): 412
#     best_fitness: np.float64(-1762504.0522980404)
# ic| iteration: 159
#     valid(solution): np.True_
#     cost(solution): np.float64(1745025.765461682)
#     len(np.where(solution)[0]): 408
#     best_fitness: np.float64(-1745025.765461682)
# ic| iteration: 160
#     valid(solution): np.True_
#     cost(solution): np.float64(1745025.765461682)
#     len(np.where(solution)[0]): 408
#     best_fitness: np.float64(-1745025.765461682)
# ic| iteration: 161
#     valid(solution): np.True_
#     cost(solution): np.float64(1745025.765461682)
#     len(np.where(solution)[0]): 408
#     best_fitness: np.float64(-1745025.765461682)
# ic| iteration: 162
#     valid(solution): np.True_
#     cost(solution): np.float64(1740167.738534817)
#     len(np.where(solution)[0]): 407
#     best_fitness: np.float64(-1740167.738534817)
# ic| iteration: 163
#     valid(solution): np.True_
#     cost(solution): np.float64(1740167.738534817)
#     len(np.where(solution)[0]): 407
#     best_fitness: np.float64(-1740167.738534817)
# ic| iteration: 164
#     valid(solution): np.True_
#     cost(solution): np.float64(1740167.738534817)
#     len(np.where(solution)[0]): 407
#     best_fitness: np.float64(-1740167.738534817)
# ic| iteration: 165
#     valid(solution): np.True_
#     cost(solution): np.float64(1740167.738534817)
#     len(np.where(solution)[0]): 407
#     best_fitness: np.float64(-1740167.738534817)
# ic| iteration: 166
#     valid(solution): np.True_
#     cost(solution): np.float64(1740167.738534817)
#     len(np.where(solution)[0]): 407
#     best_fitness: np.float64(-1740167.738534817)
# ic| iteration: 167
#     valid(solution): np.True_
#     cost(solution): np.float64(1722995.998423924)
#     len(np.where(solution)[0]): 403
#     best_fitness: np.float64(-1722995.998423924)
# ic| iteration: 168
#     valid(solution): np.True_
#     cost(solution): np.float64(1722995.998423924)
#     len(np.where(solution)[0]): 403
#     best_fitness: np.float64(-1722995.998423924)
# ic| iteration: 169
#     valid(solution): np.True_
#     cost(solution): np.float64(1722995.998423924)
#     len(np.where(solution)[0]): 403
#     best_fitness: np.float64(-1722995.998423924)
# ic| iteration: 170
#     valid(solution): np.True_
#     cost(solution): np.float64(1710156.9863408967)
#     len(np.where(solution)[0]): 400
#     best_fitness: np.float64(-1710156.9863408967)
# ic| iteration: 171
#     valid(solution): np.True_
#     cost(solution): np.float64(1710156.9863408967)
#     len(np.where(solution)[0]): 400
#     best_fitness: np.float64(-1710156.9863408967)
# ic| iteration: 172
#     valid(solution): np.True_
#     cost(solution): np.float64(1701953.6418219788)
#     len(np.where(solution)[0]): 398
#     best_fitness: np.float64(-1701953.6418219788)
# ic| iteration: 173
#     valid(solution): np.True_
#     cost(solution): np.float64(1701953.6418219788)
#     len(np.where(solution)[0]): 398
#     best_fitness: np.float64(-1701953.6418219788)
# ic| iteration: 174
#     valid(solution): np.True_
#     cost(solution): np.float64(1701953.6418219788)
#     len(np.where(solution)[0]): 398
#     best_fitness: np.float64(-1701953.6418219788)
# ic| iteration: 175
#     valid(solution): np.True_
#     cost(solution): np.float64(1693174.6213094709)
#     len(np.where(solution)[0]): 396
#     best_fitness: np.float64(-1693174.6213094709)
# ic| iteration: 176
#     valid(solution): np.True_
#     cost(solution): np.float64(1693174.6213094709)
#     len(np.where(solution)[0]): 396
#     best_fitness: np.float64(-1693174.6213094709)
# ic| iteration: 177
#     valid(solution): np.True_
#     cost(solution): np.float64(1689147.2786788438)
#     len(np.where(solution)[0]): 395
#     best_fitness: np.float64(-1689147.2786788438)
# ic| iteration: 178
#     valid(solution): np.True_
#     cost(solution): np.float64(1689147.2786788438)
#     len(np.where(solution)[0]): 395
#     best_fitness: np.float64(-1689147.2786788438)
# ic| iteration: 179
#     valid(solution): np.True_
#     cost(solution): np.float64(1689147.2786788438)
#     len(np.where(solution)[0]): 395
#     best_fitness: np.float64(-1689147.2786788438)
# ic| iteration: 180
#     valid(solution): np.True_
#     cost(solution): np.float64(1689147.2786788438)
#     len(np.where(solution)[0]): 395
#     best_fitness: np.float64(-1689147.2786788438)
# ic| iteration: 181
#     valid(solution): np.True_
#     cost(solution): np.float64(1685171.4884993152)
#     len(np.where(solution)[0]): 394
#     best_fitness: np.float64(-1685171.4884993152)
# ic| iteration: 182
#     valid(solution): np.True_
#     cost(solution): np.float64(1685171.4884993152)
#     len(np.where(solution)[0]): 394
#     best_fitness: np.float64(-1685171.4884993152)
# ic| iteration: 183
#     valid(solution): np.True_
#     cost(solution): np.float64(1685171.4884993152)
#     len(np.where(solution)[0]): 394
#     best_fitness: np.float64(-1685171.4884993152)
# ic| iteration: 184
#     valid(solution): np.True_
#     cost(solution): np.float64(1685171.4884993152)
#     len(np.where(solution)[0]): 394
#     best_fitness: np.float64(-1685171.4884993152)
# ic| iteration: 185
#     valid(solution): np.True_
#     cost(solution): np.float64(1685171.4884993152)
#     len(np.where(solution)[0]): 394
#     best_fitness: np.float64(-1685171.4884993152)
# ic| iteration: 186
#     valid(solution): np.True_
#     cost(solution): np.float64(1685171.4884993152)
#     len(np.where(solution)[0]): 394
#     best_fitness: np.float64(-1685171.4884993152)
# ic| iteration: 187
#     valid(solution): np.True_
#     cost(solution): np.float64(1685171.4884993152)
#     len(np.where(solution)[0]): 394
#     best_fitness: np.float64(-1685171.4884993152)
# ic| iteration: 188
#     valid(solution): np.True_
#     cost(solution): np.float64(1685171.4884993152)
#     len(np.where(solution)[0]): 394
#     best_fitness: np.float64(-1685171.4884993152)
# ic| iteration: 189
#     valid(solution): np.True_
#     cost(solution): np.float64(1685171.4884993152)
#     len(np.where(solution)[0]): 394
#     best_fitness: np.float64(-1685171.4884993152)
# ic| iteration: 190
#     valid(solution): np.True_
#     cost(solution): np.float64(1685171.4884993152)
#     len(np.where(solution)[0]): 394
#     best_fitness: np.float64(-1685171.4884993152)
# ic| iteration: 191
#     valid(solution): np.True_
#     cost(solution): np.float64(1685171.4884993152)
#     len(np.where(solution)[0]): 394
#     best_fitness: np.float64(-1685171.4884993152)
# ic| iteration: 192
#     valid(solution): np.True_
#     cost(solution): np.float64(1685171.4884993152)
#     len(np.where(solution)[0]): 394
#     best_fitness: np.float64(-1685171.4884993152)
# ic| iteration: 193
#     valid(solution): np.True_
#     cost(solution): np.float64(1672623.7648620235)
#     len(np.where(solution)[0]): 391
#     best_fitness: np.float64(-1672623.7648620235)
# ic| iteration: 194
#     valid(solution): np.True_
#     cost(solution): np.float64(1672623.7648620235)
#     len(np.where(solution)[0]): 391
#     best_fitness: np.float64(-1672623.7648620235)
# ic| iteration: 195
#     valid(solution): np.True_
#     cost(solution): np.float64(1655593.300822555)
#     len(np.where(solution)[0]): 387
#     best_fitness: np.float64(-1655593.300822555)
# ic| iteration: 196
#     valid(solution): np.True_
#     cost(solution): np.float64(1655593.300822555)
#     len(np.where(solution)[0]): 387
#     best_fitness: np.float64(-1655593.300822555)
# ic| iteration: 197
#     valid(solution): np.True_
#     cost(solution): np.float64(1655593.300822555)
#     len(np.where(solution)[0]): 387
#     best_fitness: np.float64(-1655593.300822555)
# ic| iteration: 198
#     valid(solution): np.True_
#     cost(solution): np.float64(1655593.300822555)
#     len(np.where(solution)[0]): 387
#     best_fitness: np.float64(-1655593.300822555)
# ic| iteration: 199
#     valid(solution): np.True_
#     cost(solution): np.float64(1655593.300822555)
#     len(np.where(solution)[0]): 387
#     best_fitness: np.float64(-1655593.300822555)
# ic| iteration: 200
#     valid(solution): np.True_
#     cost(solution): np.float64(1647406.085322469)
#     len(np.where(solution)[0]): 385
#     best_fitness: np.float64(-1647406.085322469)
# ic| iteration: 201
#     valid(solution): np.True_
#     cost(solution): np.float64(1647406.085322469)
#     len(np.where(solution)[0]): 385
#     best_fitness: np.float64(-1647406.085322469)
# ic| iteration: 202
#     valid(solution): np.True_
#     cost(solution): np.float64(1647128.3244919062)
#     len(np.where(solution)[0]): 385
#     best_fitness: np.float64(-1647128.3244919062)
# ic| iteration: 203
#     valid(solution): np.True_
#     cost(solution): np.float64(1647128.3244919062)
#     len(np.where(solution)[0]): 385
#     best_fitness: np.float64(-1647128.3244919062)
# ic| iteration: 204
#     valid(solution): np.True_
#     cost(solution): np.float64(1647128.3244919062)
#     len(np.where(solution)[0]): 385
#     best_fitness: np.float64(-1647128.3244919062)
# ic| iteration: 205
#     valid(solution): np.True_
#     cost(solution): np.float64(1629853.012089619)
#     len(np.where(solution)[0]): 381
#     best_fitness: np.float64(-1629853.012089619)
# ic| iteration: 206
#     valid(solution): np.True_
#     cost(solution): np.float64(1629853.012089619)
#     len(np.where(solution)[0]): 381
#     best_fitness: np.float64(-1629853.012089619)
# ic| iteration: 207
#     valid(solution): np.True_
#     cost(solution): np.float64(1629853.012089619)
#     len(np.where(solution)[0]): 381
#     best_fitness: np.float64(-1629853.012089619)
# ic| iteration: 208
#     valid(solution): np.True_
#     cost(solution): np.float64(1629853.012089619)
#     len(np.where(solution)[0]): 381
#     best_fitness: np.float64(-1629853.012089619)
# ic| iteration: 209
#     valid(solution): np.True_
#     cost(solution): np.float64(1629853.012089619)
#     len(np.where(solution)[0]): 381
#     best_fitness: np.float64(-1629853.012089619)
# ic| iteration: 210
#     valid(solution): np.True_
#     cost(solution): np.float64(1629853.012089619)
#     len(np.where(solution)[0]): 381
#     best_fitness: np.float64(-1629853.012089619)
# ic| iteration: 211
#     valid(solution): np.True_
#     cost(solution): np.float64(1629853.012089619)
#     len(np.where(solution)[0]): 381
#     best_fitness: np.float64(-1629853.012089619)
# ic| iteration: 212
#     valid(solution): np.True_
#     cost(solution): np.float64(1629853.012089619)
#     len(np.where(solution)[0]): 381
#     best_fitness: np.float64(-1629853.012089619)
# ic| iteration: 213
#     valid(solution): np.True_
#     cost(solution): np.float64(1629853.012089619)
#     len(np.where(solution)[0]): 381
#     best_fitness: np.float64(-1629853.012089619)
# ic| iteration: 214
#     valid(solution): np.True_
#     cost(solution): np.float64(1629853.012089619)
#     len(np.where(solution)[0]): 381
#     best_fitness: np.float64(-1629853.012089619)
# ic| iteration: 215
#     valid(solution): np.True_
#     cost(solution): np.float64(1629853.012089619)
#     len(np.where(solution)[0]): 381
#     best_fitness: np.float64(-1629853.012089619)
# ic| iteration: 216
#     valid(solution): np.True_
#     cost(solution): np.float64(1629853.012089619)
#     len(np.where(solution)[0]): 381
#     best_fitness: np.float64(-1629853.012089619)
# ic| iteration: 217
#     valid(solution): np.True_
#     cost(solution): np.float64(1629853.012089619)
#     len(np.where(solution)[0]): 381
#     best_fitness: np.float64(-1629853.012089619)
# ic| iteration: 218
#     valid(solution): np.True_
#     cost(solution): np.float64(1629853.012089619)
#     len(np.where(solution)[0]): 381
#     best_fitness: np.float64(-1629853.012089619)
# ic| iteration: 219
#     valid(solution): np.True_
#     cost(solution): np.float64(1620704.2739507142)
#     len(np.where(solution)[0]): 379
#     best_fitness: np.float64(-1620704.2739507142)
# ic| iteration: 220
#     valid(solution): np.True_
#     cost(solution): np.float64(1620673.830370095)
#     len(np.where(solution)[0]): 379
#     best_fitness: np.float64(-1620673.830370095)
# ic| iteration: 221
#     valid(solution): np.True_
#     cost(solution): np.float64(1620673.830370095)
#     len(np.where(solution)[0]): 379
#     best_fitness: np.float64(-1620673.830370095)
# ic| iteration: 222
#     valid(solution): np.True_
#     cost(solution): np.float64(1620673.830370095)
#     len(np.where(solution)[0]): 379
#     best_fitness: np.float64(-1620673.830370095)
# ic| iteration: 223
#     valid(solution): np.True_
#     cost(solution): np.float64(1620673.830370095)
#     len(np.where(solution)[0]): 379
#     best_fitness: np.float64(-1620673.830370095)
# ic| iteration: 224
#     valid(solution): np.True_
#     cost(solution): np.float64(1620673.830370095)
#     len(np.where(solution)[0]): 379
#     best_fitness: np.float64(-1620673.830370095)
# ic| iteration: 225
#     valid(solution): np.True_
#     cost(solution): np.float64(1620673.830370095)
#     len(np.where(solution)[0]): 379
#     best_fitness: np.float64(-1620673.830370095)
# ic| iteration: 226
#     valid(solution): np.True_
#     cost(solution): np.float64(1620673.830370095)
#     len(np.where(solution)[0]): 379
#     best_fitness: np.float64(-1620673.830370095)
# ic| iteration: 227
#     valid(solution): np.True_
#     cost(solution): np.float64(1620673.830370095)
#     len(np.where(solution)[0]): 379
#     best_fitness: np.float64(-1620673.830370095)
# ic| iteration: 228
#     valid(solution): np.True_
#     cost(solution): np.float64(1620673.830370095)
#     len(np.where(solution)[0]): 379
#     best_fitness: np.float64(-1620673.830370095)
# ic| iteration: 229
#     valid(solution): np.True_
#     cost(solution): np.float64(1620673.830370095)
#     len(np.where(solution)[0]): 379
#     best_fitness: np.float64(-1620673.830370095)
# ic| iteration: 230
#     valid(solution): np.True_
#     cost(solution): np.float64(1620673.830370095)
#     len(np.where(solution)[0]): 379
#     best_fitness: np.float64(-1620673.830370095)
# ic| iteration: 231
#     valid(solution): np.True_
#     cost(solution): np.float64(1620673.830370095)
#     len(np.where(solution)[0]): 379
#     best_fitness: np.float64(-1620673.830370095)
# ic| iteration: 232
#     valid(solution): np.True_
#     cost(solution): np.float64(1620673.830370095)
#     len(np.where(solution)[0]): 379
#     best_fitness: np.float64(-1620673.830370095)
# ic| iteration: 233
#     valid(solution): np.True_
#     cost(solution): np.float64(1612279.805403543)
#     len(np.where(solution)[0]): 377
#     best_fitness: np.float64(-1612279.805403543)
# ic| iteration: 234
#     valid(solution): np.True_
#     cost(solution): np.float64(1603585.1109307068)
#     len(np.where(solution)[0]): 375
#     best_fitness: np.float64(-1603585.1109307068)
# ic| iteration: 235
#     valid(solution): np.True_
#     cost(solution): np.float64(1603585.1109307068)
#     len(np.where(solution)[0]): 375
#     best_fitness: np.float64(-1603585.1109307068)
# ic| iteration: 236
#     valid(solution): np.True_
#     cost(solution): np.float64(1603585.1109307068)
#     len(np.where(solution)[0]): 375
#     best_fitness: np.float64(-1603585.1109307068)
# ic| iteration: 237
#     valid(solution): np.True_
#     cost(solution): np.float64(1603585.1109307068)
#     len(np.where(solution)[0]): 375
#     best_fitness: np.float64(-1603585.1109307068)
# ic| iteration: 238
#     valid(solution): np.True_
#     cost(solution): np.float64(1603585.1109307068)
#     len(np.where(solution)[0]): 375
#     best_fitness: np.float64(-1603585.1109307068)
# ic| iteration: 239
#     valid(solution): np.True_
#     cost(solution): np.float64(1603559.2530489333)
#     len(np.where(solution)[0]): 375
#     best_fitness: np.float64(-1603559.2530489333)
# ic| iteration: 240
#     valid(solution): np.True_
#     cost(solution): np.float64(1603559.2530489333)
#     len(np.where(solution)[0]): 375
#     best_fitness: np.float64(-1603559.2530489333)
# ic| iteration: 241
#     valid(solution): np.True_
#     cost(solution): np.float64(1603559.2530489333)
#     len(np.where(solution)[0]): 375
#     best_fitness: np.float64(-1603559.2530489333)
# ic| iteration: 242
#     valid(solution): np.True_
#     cost(solution): np.float64(1603559.2530489333)
#     len(np.where(solution)[0]): 375
#     best_fitness: np.float64(-1603559.2530489333)
# ic| iteration: 243
#     valid(solution): np.True_
#     cost(solution): np.float64(1599529.4329516967)
#     len(np.where(solution)[0]): 374
#     best_fitness: np.float64(-1599529.4329516967)
# ic| iteration: 244
#     valid(solution): np.True_
#     cost(solution): np.float64(1599529.4329516967)
#     len(np.where(solution)[0]): 374
#     best_fitness: np.float64(-1599529.4329516967)
# ic| iteration: 245
#     valid(solution): np.True_
#     cost(solution): np.float64(1599529.4329516967)
#     len(np.where(solution)[0]): 374
#     best_fitness: np.float64(-1599529.4329516967)
# ic| iteration: 246
#     valid(solution): np.True_
#     cost(solution): np.float64(1599529.4329516967)
#     len(np.where(solution)[0]): 374
#     best_fitness: np.float64(-1599529.4329516967)
# ic| iteration: 247
#     valid(solution): np.True_
#     cost(solution): np.float64(1599529.4329516967)
#     len(np.where(solution)[0]): 374
#     best_fitness: np.float64(-1599529.4329516967)
# ic| iteration: 248
#     valid(solution): np.True_
#     cost(solution): np.float64(1599529.4329516967)
#     len(np.where(solution)[0]): 374
#     best_fitness: np.float64(-1599529.4329516967)
# ic| iteration: 249
#     valid(solution): np.True_
#     cost(solution): np.float64(1599529.4329516967)
#     len(np.where(solution)[0]): 374
#     best_fitness: np.float64(-1599529.4329516967)
# ic| iteration: 250
#     valid(solution): np.True_
#     cost(solution): np.float64(1599529.4329516967)
#     len(np.where(solution)[0]): 374
#     best_fitness: np.float64(-1599529.4329516967)
# ic| iteration: 251
#     valid(solution): np.True_
#     cost(solution): np.float64(1599529.4329516967)
#     len(np.where(solution)[0]): 374
#     best_fitness: np.float64(-1599529.4329516967)
# ic| iteration: 252
#     valid(solution): np.True_
#     cost(solution): np.float64(1599529.4329516967)
#     len(np.where(solution)[0]): 374
#     best_fitness: np.float64(-1599529.4329516967)
# ic| iteration: 253
#     valid(solution): np.True_
#     cost(solution): np.float64(1595195.4795654723)
#     len(np.where(solution)[0]): 373
#     best_fitness: np.float64(-1595195.4795654723)
# ic| iteration: 254
#     valid(solution): np.True_
#     cost(solution): np.float64(1595195.4795654723)
#     len(np.where(solution)[0]): 373
#     best_fitness: np.float64(-1595195.4795654723)
# ic| iteration: 255
#     valid(solution): np.True_
#     cost(solution): np.float64(1595195.4795654723)
#     len(np.where(solution)[0]): 373
#     best_fitness: np.float64(-1595195.4795654723)
# ic| iteration: 256
#     valid(solution): np.True_
#     cost(solution): np.float64(1595195.4795654723)
#     len(np.where(solution)[0]): 373
#     best_fitness: np.float64(-1595195.4795654723)
# ic| iteration: 257
#     valid(solution): np.True_
#     cost(solution): np.float64(1595195.4795654723)
#     len(np.where(solution)[0]): 373
#     best_fitness: np.float64(-1595195.4795654723)
# ic| iteration: 258
#     valid(solution): np.True_
#     cost(solution): np.float64(1595195.4795654723)
#     len(np.where(solution)[0]): 373
#     best_fitness: np.float64(-1595195.4795654723)
# ic| iteration: 259
#     valid(solution): np.True_
#     cost(solution): np.float64(1595195.4795654723)
#     len(np.where(solution)[0]): 373
# ...
#     valid(solution): np.True_
#     cost(solution): np.float64(1123312.013460915)
#     len(np.where(solution)[0]): 263
#     best_fitness: np.float64(-1123312.013460915)
# ic| iteration: 915
#     valid(solution): np.True_
#     cost(solution): np.float64(1123312.013460915)
#     len(np.where(solution)[0]): 263
#     best_fitness: np.float64(-1123312.013460915)
# ic| iteration: 916
#     valid(solution): np.True_
#     cost(solution): np.float64(1123312.013460915)
#     len(np.where(solution)[0]): 263
#     best_fitness: np.float64(-1123312.013460915)
# ic| iteration: 917
#     valid(solution): np.True_
#     cost(solution): np.float64(1123307.5078480346)
#     len(np.where(solution)[0]): 263
#     best_fitness: np.float64(-1123307.5078480346)
# ic| iteration: 918
#     valid(solution): np.True_
#     cost(solution): np.float64(1123307.5078480346)
#     len(np.where(solution)[0]): 263
#     best_fitness: np.float64(-1123307.5078480346)
# ic| iteration: 919
#     valid(solution): np.True_
#     cost(solution): np.float64(1123307.5078480346)
#     len(np.where(solution)[0]): 263
#     best_fitness: np.float64(-1123307.5078480346)
# ic| iteration: 920
#     valid(solution): np.True_
#     cost(solution): np.float64(1123307.5078480346)
#     len(np.where(solution)[0]): 263
#     best_fitness: np.float64(-1123307.5078480346)
# ic| iteration: 921
#     valid(solution): np.True_
#     cost(solution): np.float64(1123307.5078480346)
#     len(np.where(solution)[0]): 263
#     best_fitness: np.float64(-1123307.5078480346)
# ic| iteration: 922
#     valid(solution): np.True_
#     cost(solution): np.float64(1123307.5078480346)
#     len(np.where(solution)[0]): 263
#     best_fitness: np.float64(-1123307.5078480346)
# ic| iteration: 923
#     valid(solution): np.True_
#     cost(solution): np.float64(1123307.5078480346)
#     len(np.where(solution)[0]): 263
#     best_fitness: np.float64(-1123307.5078480346)
# ic| iteration: 924
#     valid(solution): np.True_
#     cost(solution): np.float64(1123307.5078480346)
#     len(np.where(solution)[0]): 263
#     best_fitness: np.float64(-1123307.5078480346)
# ic| iteration: 925
#     valid(solution): np.True_
#     cost(solution): np.float64(1123307.5078480346)
#     len(np.where(solution)[0]): 263
#     best_fitness: np.float64(-1123307.5078480346)
# ic| iteration: 926
#     valid(solution): np.True_
#     cost(solution): np.float64(1123166.8865271725)
#     len(np.where(solution)[0]): 263
#     best_fitness: np.float64(-1123166.8865271725)
# ic| iteration: 927
#     valid(solution): np.True_
#     cost(solution): np.float64(1123166.8865271725)
#     len(np.where(solution)[0]): 263
#     best_fitness: np.float64(-1123166.8865271725)
# ic| iteration: 928
#     valid(solution): np.True_
#     cost(solution): np.float64(1123166.8865271725)
#     len(np.where(solution)[0]): 263
#     best_fitness: np.float64(-1123166.8865271725)
# ic| iteration: 929
#     valid(solution): np.True_
#     cost(solution): np.float64(1123166.8865271725)
#     len(np.where(solution)[0]): 263
#     best_fitness: np.float64(-1123166.8865271725)
# ic| iteration: 930
#     valid(solution): np.True_
#     cost(solution): np.float64(1123166.8865271725)
#     len(np.where(solution)[0]): 263
#     best_fitness: np.float64(-1123166.8865271725)
# ic| iteration: 931
#     valid(solution): np.True_
#     cost(solution): np.float64(1123166.8865271725)
#     len(np.where(solution)[0]): 263
#     best_fitness: np.float64(-1123166.8865271725)
# ic| iteration: 932
#     valid(solution): np.True_
#     cost(solution): np.float64(1123166.8865271725)
#     len(np.where(solution)[0]): 263
#     best_fitness: np.float64(-1123166.8865271725)
# ic| iteration: 933
#     valid(solution): np.True_
#     cost(solution): np.float64(1123166.8865271725)
#     len(np.where(solution)[0]): 263
#     best_fitness: np.float64(-1123166.8865271725)
# ic| iteration: 934
#     valid(solution): np.True_
#     cost(solution): np.float64(1123166.8865271725)
#     len(np.where(solution)[0]): 263
#     best_fitness: np.float64(-1123166.8865271725)
# ic| iteration: 935
#     valid(solution): np.True_
#     cost(solution): np.float64(1123166.8865271725)
#     len(np.where(solution)[0]): 263
#     best_fitness: np.float64(-1123166.8865271725)
# ic| iteration: 936
#     valid(solution): np.True_
#     cost(solution): np.float64(1123166.8865271725)
#     len(np.where(solution)[0]): 263
#     best_fitness: np.float64(-1123166.8865271725)
# ic| iteration: 937
#     valid(solution): np.True_
#     cost(solution): np.float64(1123166.8865271725)
#     len(np.where(solution)[0]): 263
#     best_fitness: np.float64(-1123166.8865271725)
# ic| iteration: 938
#     valid(solution): np.True_
#     cost(solution): np.float64(1123166.8865271725)
#     len(np.where(solution)[0]): 263
#     best_fitness: np.float64(-1123166.8865271725)
# ic| iteration: 939
#     valid(solution): np.True_
#     cost(solution): np.float64(1123166.8865271725)
#     len(np.where(solution)[0]): 263
#     best_fitness: np.float64(-1123166.8865271725)
# ic| iteration: 940
#     valid(solution): np.True_
#     cost(solution): np.float64(1123166.8865271725)
#     len(np.where(solution)[0]): 263
#     best_fitness: np.float64(-1123166.8865271725)
# ic| iteration: 941
#     valid(solution): np.True_
#     cost(solution): np.float64(1123166.8865271725)
#     len(np.where(solution)[0]): 263
#     best_fitness: np.float64(-1123166.8865271725)
# ic| iteration: 942
#     valid(solution): np.True_
#     cost(solution): np.float64(1115010.980497607)
#     len(np.where(solution)[0]): 261
#     best_fitness: np.float64(-1115010.980497607)
# ic| iteration: 943
#     valid(solution): np.True_
#     cost(solution): np.float64(1115010.980497607)
#     len(np.where(solution)[0]): 261
#     best_fitness: np.float64(-1115010.980497607)
# ic| iteration: 944
#     valid(solution): np.True_
#     cost(solution): np.float64(1115010.980497607)
#     len(np.where(solution)[0]): 261
#     best_fitness: np.float64(-1115010.980497607)
# ic| iteration: 945
#     valid(solution): np.True_
#     cost(solution): np.float64(1115010.980497607)
#     len(np.where(solution)[0]): 261
#     best_fitness: np.float64(-1115010.980497607)
# ic| iteration: 946
#     valid(solution): np.True_
#     cost(solution): np.float64(1115010.980497607)
#     len(np.where(solution)[0]): 261
#     best_fitness: np.float64(-1115010.980497607)
# ic| iteration: 947
#     valid(solution): np.True_
#     cost(solution): np.float64(1115010.980497607)
#     len(np.where(solution)[0]): 261
#     best_fitness: np.float64(-1115010.980497607)
# ic| iteration: 948
#     valid(solution): np.True_
#     cost(solution): np.float64(1115010.980497607)
#     len(np.where(solution)[0]): 261
#     best_fitness: np.float64(-1115010.980497607)
# ic| iteration: 949
#     valid(solution): np.True_
#     cost(solution): np.float64(1115010.980497607)
#     len(np.where(solution)[0]): 261
#     best_fitness: np.float64(-1115010.980497607)
# ic| iteration: 950
#     valid(solution): np.True_
#     cost(solution): np.float64(1115010.980497607)
#     len(np.where(solution)[0]): 261
#     best_fitness: np.float64(-1115010.980497607)
# ic| iteration: 951
#     valid(solution): np.True_
#     cost(solution): np.float64(1115010.980497607)
#     len(np.where(solution)[0]): 261
#     best_fitness: np.float64(-1115010.980497607)
# ic| iteration: 952
#     valid(solution): np.True_
#     cost(solution): np.float64(1115010.980497607)
#     len(np.where(solution)[0]): 261
#     best_fitness: np.float64(-1115010.980497607)
# ic| iteration: 953
#     valid(solution): np.True_
#     cost(solution): np.float64(1115010.980497607)
#     len(np.where(solution)[0]): 261
#     best_fitness: np.float64(-1115010.980497607)
# ic| iteration: 954
#     valid(solution): np.True_
#     cost(solution): np.float64(1115010.980497607)
#     len(np.where(solution)[0]): 261
#     best_fitness: np.float64(-1115010.980497607)
# ic| iteration: 955
#     valid(solution): np.True_
#     cost(solution): np.float64(1115010.980497607)
#     len(np.where(solution)[0]): 261
#     best_fitness: np.float64(-1115010.980497607)
# ic| iteration: 956
#     valid(solution): np.True_
#     cost(solution): np.float64(1115010.980497607)
#     len(np.where(solution)[0]): 261
#     best_fitness: np.float64(-1115010.980497607)
# ic| iteration: 957
#     valid(solution): np.True_
#     cost(solution): np.float64(1115010.980497607)
#     len(np.where(solution)[0]): 261
#     best_fitness: np.float64(-1115010.980497607)
# ic| iteration: 958
#     valid(solution): np.True_
#     cost(solution): np.float64(1115010.980497607)
#     len(np.where(solution)[0]): 261
#     best_fitness: np.float64(-1115010.980497607)
# ic| iteration: 959
#     valid(solution): np.True_
#     cost(solution): np.float64(1115010.980497607)
#     len(np.where(solution)[0]): 261
#     best_fitness: np.float64(-1115010.980497607)
# ic| iteration: 960
#     valid(solution): np.True_
#     cost(solution): np.float64(1115010.980497607)
#     len(np.where(solution)[0]): 261
#     best_fitness: np.float64(-1115010.980497607)
# ic| iteration: 961
#     valid(solution): np.True_
#     cost(solution): np.float64(1115010.980497607)
#     len(np.where(solution)[0]): 261
#     best_fitness: np.float64(-1115010.980497607)
# ic| iteration: 962
#     valid(solution): np.True_
#     cost(solution): np.float64(1115010.980497607)
#     len(np.where(solution)[0]): 261
#     best_fitness: np.float64(-1115010.980497607)
# ic| iteration: 963
#     valid(solution): np.True_
#     cost(solution): np.float64(1110838.6733144075)
#     len(np.where(solution)[0]): 260
#     best_fitness: np.float64(-1110838.6733144075)
# ic| iteration: 964
#     valid(solution): np.True_
#     cost(solution): np.float64(1110838.6733144075)
#     len(np.where(solution)[0]): 260
#     best_fitness: np.float64(-1110838.6733144075)
# ic| iteration: 965
#     valid(solution): np.True_
#     cost(solution): np.float64(1110838.6733144075)
#     len(np.where(solution)[0]): 260
#     best_fitness: np.float64(-1110838.6733144075)
# ic| iteration: 966
#     valid(solution): np.True_
#     cost(solution): np.float64(1110838.6733144075)
#     len(np.where(solution)[0]): 260
#     best_fitness: np.float64(-1110838.6733144075)
# ic| iteration: 967
#     valid(solution): np.True_
#     cost(solution): np.float64(1110838.6733144075)
#     len(np.where(solution)[0]): 260
#     best_fitness: np.float64(-1110838.6733144075)
# ic| iteration: 968
#     valid(solution): np.True_
#     cost(solution): np.float64(1110838.6733144075)
#     len(np.where(solution)[0]): 260
#     best_fitness: np.float64(-1110838.6733144075)
# ic| iteration: 969
#     valid(solution): np.True_
#     cost(solution): np.float64(1110838.6733144075)
#     len(np.where(solution)[0]): 260
#     best_fitness: np.float64(-1110838.6733144075)
# ic| iteration: 970
#     valid(solution): np.True_
#     cost(solution): np.float64(1110838.6733144075)
#     len(np.where(solution)[0]): 260
#     best_fitness: np.float64(-1110838.6733144075)
# ic| iteration: 971
#     valid(solution): np.True_
#     cost(solution): np.float64(1110838.6733144075)
#     len(np.where(solution)[0]): 260
#     best_fitness: np.float64(-1110838.6733144075)
# ic| iteration: 972
#     valid(solution): np.True_
#     cost(solution): np.float64(1110838.6733144075)
#     len(np.where(solution)[0]): 260
#     best_fitness: np.float64(-1110838.6733144075)
# ic| iteration: 973
#     valid(solution): np.True_
#     cost(solution): np.float64(1110838.6733144075)
#     len(np.where(solution)[0]): 260
#     best_fitness: np.float64(-1110838.6733144075)
# ic| iteration: 974
#     valid(solution): np.True_
#     cost(solution): np.float64(1110838.6733144075)
#     len(np.where(solution)[0]): 260
#     best_fitness: np.float64(-1110838.6733144075)
# ic| iteration: 975
#     valid(solution): np.True_
#     cost(solution): np.float64(1110838.6733144075)
#     len(np.where(solution)[0]): 260
#     best_fitness: np.float64(-1110838.6733144075)
# ic| iteration: 976
#     valid(solution): np.True_
#     cost(solution): np.float64(1110838.6733144075)
#     len(np.where(solution)[0]): 260
#     best_fitness: np.float64(-1110838.6733144075)
# ic| iteration: 977
#     valid(solution): np.True_
#     cost(solution): np.float64(1110838.6733144075)
#     len(np.where(solution)[0]): 260
#     best_fitness: np.float64(-1110838.6733144075)
# ic| iteration: 978
#     valid(solution): np.True_
#     cost(solution): np.float64(1110838.6733144075)
#     len(np.where(solution)[0]): 260
#     best_fitness: np.float64(-1110838.6733144075)
# ic| iteration: 979
#     valid(solution): np.True_
#     cost(solution): np.float64(1110838.6733144075)
#     len(np.where(solution)[0]): 260
#     best_fitness: np.float64(-1110838.6733144075)
# ic| iteration: 980
#     valid(solution): np.True_
#     cost(solution): np.float64(1110838.6733144075)
#     len(np.where(solution)[0]): 260
#     best_fitness: np.float64(-1110838.6733144075)
# ic| iteration: 981
#     valid(solution): np.True_
#     cost(solution): np.float64(1110838.6733144075)
#     len(np.where(solution)[0]): 260
#     best_fitness: np.float64(-1110838.6733144075)
# ic| iteration: 982
#     valid(solution): np.True_
#     cost(solution): np.float64(1110838.6733144075)
#     len(np.where(solution)[0]): 260
#     best_fitness: np.float64(-1110838.6733144075)
# ic| iteration: 983
#     valid(solution): np.True_
#     cost(solution): np.float64(1110838.6733144075)
#     len(np.where(solution)[0]): 260
#     best_fitness: np.float64(-1110838.6733144075)
# ic| iteration: 984
#     valid(solution): np.True_
#     cost(solution): np.float64(1110838.6733144075)
#     len(np.where(solution)[0]): 260
#     best_fitness: np.float64(-1110838.6733144075)
# ic| iteration: 985
#     valid(solution): np.True_
#     cost(solution): np.float64(1110838.6733144075)
#     len(np.where(solution)[0]): 260
#     best_fitness: np.float64(-1110838.6733144075)
# ic| iteration: 986
#     valid(solution): np.True_
#     cost(solution): np.float64(1110838.6733144075)
#     len(np.where(solution)[0]): 260
#     best_fitness: np.float64(-1110838.6733144075)
# ic| iteration: 987
#     valid(solution): np.True_
#     cost(solution): np.float64(1110838.6733144075)
#     len(np.where(solution)[0]): 260
#     best_fitness: np.float64(-1110838.6733144075)
# ic| iteration: 988
#     valid(solution): np.True_
#     cost(solution): np.float64(1110838.6733144075)
#     len(np.where(solution)[0]): 260
#     best_fitness: np.float64(-1110838.6733144075)
# ic| iteration: 989
#     valid(solution): np.True_
#     cost(solution): np.float64(1110838.6733144075)
#     len(np.where(solution)[0]): 260
#     best_fitness: np.float64(-1110838.6733144075)
# ic| iteration: 990
#     valid(solution): np.True_
#     cost(solution): np.float64(1110838.6733144075)
#     len(np.where(solution)[0]): 260
#     best_fitness: np.float64(-1110838.6733144075)
# ic| iteration: 991
#     valid(solution): np.True_
#     cost(solution): np.float64(1110838.6733144075)
#     len(np.where(solution)[0]): 260
#     best_fitness: np.float64(-1110838.6733144075)
# ic| iteration: 992
#     valid(solution): np.True_
#     cost(solution): np.float64(1110838.6733144075)
#     len(np.where(solution)[0]): 260
#     best_fitness: np.float64(-1110838.6733144075)
# ic| iteration: 993
#     valid(solution): np.True_
#     cost(solution): np.float64(1110838.6733144075)
#     len(np.where(solution)[0]): 260
#     best_fitness: np.float64(-1110838.6733144075)
# ic| iteration: 994
#     valid(solution): np.True_
#     cost(solution): np.float64(1110838.6733144075)
#     len(np.where(solution)[0]): 260
#     best_fitness: np.float64(-1110838.6733144075)
# ic| iteration: 995
#     valid(solution): np.True_
#     cost(solution): np.float64(1110838.6733144075)
#     len(np.where(solution)[0]): 260
#     best_fitness: np.float64(-1110838.6733144075)
# ic| iteration: 996
#     valid(solution): np.True_
#     cost(solution): np.float64(1110838.6733144075)
#     len(np.where(solution)[0]): 260
#     best_fitness: np.float64(-1110838.6733144075)
# ic| iteration: 997
#     valid(solution): np.True_
#     cost(solution): np.float64(1110838.6733144075)
#     len(np.where(solution)[0]): 260
#     best_fitness: np.float64(-1110838.6733144075)
# ic| iteration: 998
#     valid(solution): np.True_
#     cost(solution): np.float64(1110838.6733144075)
#     len(np.where(solution)[0]): 260
#     best_fitness: np.float64(-1110838.6733144075)
# ic| iteration: 999
#     valid(solution): np.True_
#     cost(solution): np.float64(1110838.6733144075)
#     len(np.where(solution)[0]): 260
#     best_fitness: np.float64(-1110838.6733144075)
# Best solution (multiple tweak) cost: 1110838.6733144075

# %% [markdown]
# **Tweak and Restart**

# %%
# Tweak and Restart algorithm
def tweak_and_restart(max_restarts=100):
    best_solution = np.full(NUM_SETS, True)  # Initial "best" solution with all sets
    
    for restart in range(max_restarts):
        # Start with no sets
        solution = np.full(NUM_SETS, False)

        # Randomly add sets until the solution is valid
        while not valid(solution):
            index = rng.integers(0, NUM_SETS)
            solution[index] = True
        
        # Check if the new solution has a lower cost
        if cost(solution) < cost(best_solution):
            best_solution = solution.copy()

        ic(restart, valid(solution), cost(solution), len(np.where(solution)[0]), cost(best_solution))

    return best_solution, cost(best_solution)

# Run the tweak and restart algorithm
best_solution, best_cost = tweak_and_restart(max_restarts=100)
print(f"Best solution found with tweak and restart: {best_cost}")
# Out:
# ic| restart: 0
#     valid(solution): np.True_
#     cost(solution): np.float64(183369.30966859363)
#     len(np.where(solution)[0]): 43
#     cost(best_solution): np.float64(183369.30966859363)
# ic| restart: 1
#     valid(solution): np.True_
#     cost(solution): np.float64(157881.10944030635)
#     len(np.where(solution)[0]): 37
#     cost(best_solution): np.float64(157881.10944030635)
# ic| restart: 2
#     valid(solution): np.True_
#     cost(solution): np.float64(157833.16821861753)
#     len(np.where(solution)[0]): 37
#     cost(best_solution): np.float64(157833.16821861753)
# ic| restart: 3
#     valid(solution): np.True_
#     cost(solution): np.float64(227258.50401691897)
#     len(np.where(solution)[0]): 53
#     cost(best_solution): np.float64(157833.16821861753)
# ic| restart: 4
#     valid(solution): np.True_
#     cost(solution): np.float64(201126.99484993736)
#     len(np.where(solution)[0]): 47
#     cost(best_solution): np.float64(157833.16821861753)
# ic| restart: 5
#     valid(solution): np.True_
#     cost(solution): np.float64(171508.70985675958)
#     len(np.where(solution)[0]): 40
#     cost(best_solution): np.float64(157833.16821861753)
# ic| restart: 6
#     valid(solution): np.True_
#     cost(solution): np.float64(231736.8681629073)
#     len(np.where(solution)[0]): 54
#     cost(best_solution): np.float64(157833.16821861753)
# ic| restart: 7
#     valid(solution): np.True_
#     cost(solution): np.float64(183216.53503581067)
#     len(np.where(solution)[0]): 43
#     cost(best_solution): np.float64(157833.16821861753)
# ic| restart: 8
#     valid(solution): np.True_
#     cost(solution): np.float64(230702.05179237743)
#     len(np.where(solution)[0]): 54
#     cost(best_solution): np.float64(157833.16821861753)
# ic| restart: 9
#     valid(solution): np.True_
#     cost(solution): np.float64(201373.0290061863)
#     len(np.where(solution)[0]): 47
#     cost(best_solution): np.float64(157833.16821861753)
# ic| restart: 10
#     valid(solution): np.True_
#     cost(solution): np.float64(162821.4867443122)
#     len(np.where(solution)[0]): 38
#     cost(best_solution): np.float64(157833.16821861753)
# ic| restart: 11
#     valid(solution): np.True_
#     cost(solution): np.float64(184423.03652294216)
#     len(np.where(solution)[0]): 43
#     cost(best_solution): np.float64(157833.16821861753)
# ic| restart: 12
#     valid(solution): np.True_
#     cost(solution): np.float64(171308.11497776367)
#     len(np.where(solution)[0]): 40
#     cost(best_solution): np.float64(157833.16821861753)
# ic| restart: 13
#     valid(solution): np.True_
#     cost(solution): np.float64(166946.55036262306)
#     len(np.where(solution)[0]): 39
#     cost(best_solution): np.float64(157833.16821861753)
# ic| restart: 14
#     valid(solution): np.True_
#     cost(solution): np.float64(188746.64498637329)
#     len(np.where(solution)[0]): 44
#     cost(best_solution): np.float64(157833.16821861753)
# ic| restart: 15
#     valid(solution): np.True_
#     cost(solution): np.float64(192128.00595705202)
#     len(np.where(solution)[0]): 45
#     cost(best_solution): np.float64(157833.16821861753)
# ic| restart: 16
#     valid(solution): np.True_
#     cost(solution): np.float64(196754.1302113231)
#     len(np.where(solution)[0]): 46
#     cost(best_solution): np.float64(157833.16821861753)
# ic| restart: 17
#     valid(solution): np.True_
#     cost(solution): np.float64(205609.5417103083)
#     len(np.where(solution)[0]): 48
#     cost(best_solution): np.float64(157833.16821861753)
# ic| restart: 18
#     valid(solution): np.True_
#     cost(solution): np.float64(204638.10077154788)
#     len(np.where(solution)[0]): 48
#     cost(best_solution): np.float64(157833.16821861753)
# ic| restart: 19
#     valid(solution): np.True_
#     cost(solution): np.float64(175461.4698556542)
#     len(np.where(solution)[0]): 41
#     cost(best_solution): np.float64(157833.16821861753)
# ic| restart: 20
#     valid(solution): np.True_
#     cost(solution): np.float64(205590.6793357446)
#     len(np.where(solution)[0]): 48
#     cost(best_solution): np.float64(157833.16821861753)
# ic| restart: 21
#     valid(solution): np.True_
#     cost(solution): np.float64(217732.37941567888)
#     len(np.where(solution)[0]): 51
#     cost(best_solution): np.float64(157833.16821861753)
# ic| restart: 22
#     valid(solution): np.True_
#     cost(solution): np.float64(185030.16621916086)
#     len(np.where(solution)[0]): 43
#     cost(best_solution): np.float64(157833.16821861753)
# ic| restart: 23
#     valid(solution): np.True_
#     cost(solution): np.float64(160043.01009907253)
#     len(np.where(solution)[0]): 37
#     cost(best_solution): np.float64(157833.16821861753)
# ic| restart: 24
#     valid(solution): np.True_
#     cost(solution): np.float64(201580.33876139636)
#     len(np.where(solution)[0]): 47
#     cost(best_solution): np.float64(157833.16821861753)
# ic| restart: 25
#     valid(solution): np.True_
#     cost(solution): np.float64(235034.08223635211)
#     len(np.where(solution)[0]): 55
#     cost(best_solution): np.float64(157833.16821861753)
# ic| restart: 26
#     valid(solution): np.True_
#     cost(solution): np.float64(168151.263023198)
#     len(np.where(solution)[0]): 39
#     cost(best_solution): np.float64(157833.16821861753)
# ic| restart: 27
#     valid(solution): np.True_
#     cost(solution): np.float64(205000.454326296)
#     len(np.where(solution)[0]): 48
#     cost(best_solution): np.float64(157833.16821861753)
# ic| restart: 28
#     valid(solution): np.True_
#     cost(solution): np.float64(196467.18638626684)
#     len(np.where(solution)[0]): 46
#     cost(best_solution): np.float64(157833.16821861753)
# ic| restart: 29
#     valid(solution): np.True_
#     cost(solution): np.float64(171959.46653019468)
#     len(np.where(solution)[0]): 40
#     cost(best_solution): np.float64(157833.16821861753)
# ic| restart: 30
#     valid(solution): np.True_
#     cost(solution): np.float64(166172.35150486804)
#     len(np.where(solution)[0]): 39
#     cost(best_solution): np.float64(157833.16821861753)
# ic| restart: 31
#     valid(solution): np.True_
#     cost(solution): np.float64(162194.40775161525)
#     len(np.where(solution)[0]): 38
#     cost(best_solution): np.float64(157833.16821861753)
# ic| restart: 32
#     valid(solution): np.True_
#     cost(solution): np.float64(192412.1482956976)
#     len(np.where(solution)[0]): 45
#     cost(best_solution): np.float64(157833.16821861753)
# ic| restart: 33
#     valid(solution): np.True_
#     cost(solution): np.float64(184120.12232506732)
#     len(np.where(solution)[0]): 43
#     cost(best_solution): np.float64(157833.16821861753)
# ic| restart: 34
#     valid(solution): np.True_
#     cost(solution): np.float64(209859.07660622915)
#     len(np.where(solution)[0]): 49
#     cost(best_solution): np.float64(157833.16821861753)
# ic| restart: 35
#     valid(solution): np.True_
#     cost(solution): np.float64(204233.68654402427)
#     len(np.where(solution)[0]): 48
#     cost(best_solution): np.float64(157833.16821861753)
# ic| restart: 36
#     valid(solution): np.True_
#     cost(solution): np.float64(188253.5907775642)
#     len(np.where(solution)[0]): 44
#     cost(best_solution): np.float64(157833.16821861753)
# ic| restart: 37
#     valid(solution): np.True_
#     cost(solution): np.float64(197512.8138799146)
#     len(np.where(solution)[0]): 46
#     cost(best_solution): np.float64(157833.16821861753)
# ic| restart: 38
#     valid(solution): np.True_
#     cost(solution): np.float64(218024.37848673802)
#     len(np.where(solution)[0]): 51
#     cost(best_solution): np.float64(157833.16821861753)
# ic| restart: 39
#     valid(solution): np.True_
#     cost(solution): np.float64(193965.75061117232)
#     len(np.where(solution)[0]): 45
#     cost(best_solution): np.float64(157833.16821861753)
# ic| restart: 40
#     valid(solution): np.True_
#     cost(solution): np.float64(175198.2848931058)
#     len(np.where(solution)[0]): 41
#     cost(best_solution): np.float64(157833.16821861753)
# ic| restart: 41
#     valid(solution): np.True_
#     cost(solution): np.float64(197185.15863680167)
#     len(np.where(solution)[0]): 46
#     cost(best_solution): np.float64(157833.16821861753)
# ic| restart: 42
#     valid(solution): np.True_
#     cost(solution): np.float64(223279.98465193366)
#     len(np.where(solution)[0]): 52
#     cost(best_solution): np.float64(157833.16821861753)
# ic| restart: 43
#     valid(solution): np.True_
#     cost(solution): np.float64(179998.21116338123)
#     len(np.where(solution)[0]): 42
#     cost(best_solution): np.float64(157833.16821861753)
# ic| restart: 44
#     valid(solution): np.True_
#     cost(solution): np.float64(189092.37002037725)
#     len(np.where(solution)[0]): 44
#     cost(best_solution): np.float64(157833.16821861753)
# ic| restart: 45
#     valid(solution): np.True_
#     cost(solution): np.float64(179473.71507322844)
#     len(np.where(solution)[0]): 42
#     cost(best_solution): np.float64(157833.16821861753)
# ic| restart: 46
#     valid(solution): np.True_
#     cost(solution): np.float64(175713.63015837714)
#     len(np.where(solution)[0]): 41
#     cost(best_solution): np.float64(157833.16821861753)
# ic| restart: 47
#     valid(solution): np.True_
#     cost(solution): np.float64(188095.8263366587)
#     len(np.where(solution)[0]): 44
#     cost(best_solution): np.float64(157833.16821861753)
# ic| restart: 48
#     valid(solution): np.True_
#     cost(solution): np.float64(188982.1744308331)
#     len(np.where(solution)[0]): 44
#     cost(best_solution): np.float64(157833.16821861753)
# ic| restart: 49
#     valid(solution): np.True_
#     cost(solution): np.float64(193322.10118617248)
#     len(np.where(solution)[0]): 45
#     cost(best_solution): np.float64(157833.16821861753)
# ic| restart: 50
#     valid(solution): np.True_
#     cost(solution): np.float64(158217.81636988456)
#     len(np.where(solution)[0]): 37
#     cost(best_solution): np.float64(157833.16821861753)
# ic| restart: 51
#     valid(solution): np.True_
#     cost(solution): np.float64(179208.67083843146)
#     len(np.where(solution)[0]): 42
#     cost(best_solution): np.float64(157833.16821861753)
# ic| restart: 52
#     valid(solution): np.True_
#     cost(solution): np.float64(193550.71464546298)
#     len(np.where(solution)[0]): 45
#     cost(best_solution): np.float64(157833.16821861753)
# ic| restart: 53
#     valid(solution): np.True_
#     cost(solution): np.float64(187170.61039295344)
#     len(np.where(solution)[0]): 44
#     cost(best_solution): np.float64(157833.16821861753)
# ic| restart: 54
#     valid(solution): np.True_
#     cost(solution): np.float64(192892.44228714128)
#     len(np.where(solution)[0]): 45
#     cost(best_solution): np.float64(157833.16821861753)
# ic| restart: 55
#     valid(solution): np.True_
#     cost(solution): np.float64(213981.65084598295)
#     len(np.where(solution)[0]): 50
#     cost(best_solution): np.float64(157833.16821861753)
# ic| restart: 56
#     valid(solution): np.True_
#     cost(solution): np.float64(175486.9609523881)
#     len(np.where(solution)[0]): 41
#     cost(best_solution): np.float64(157833.16821861753)
# ic| restart: 57
#     valid(solution): np.True_
#     cost(solution): np.float64(171511.33427057555)
#     len(np.where(solution)[0]): 40
#     cost(best_solution): np.float64(157833.16821861753)
# ic| restart: 58
#     valid(solution): np.True_
#     cost(solution): np.float64(238648.02180147415)
#     len(np.where(solution)[0]): 56
#     cost(best_solution): np.float64(157833.16821861753)
# ic| restart: 59
#     valid(solution): np.True_
#     cost(solution): np.float64(214223.5366596521)
#     len(np.where(solution)[0]): 50
#     cost(best_solution): np.float64(157833.16821861753)
# ic| restart: 60
#     valid(solution): np.True_
#     cost(solution): np.float64(205072.65363382694)
#     len(np.where(solution)[0]): 48
#     cost(best_solution): np.float64(157833.16821861753)
# ic| restart: 61
#     valid(solution): np.True_
#     cost(solution): np.float64(202214.3450981197)
#     len(np.where(solution)[0]): 47
#     cost(best_solution): np.float64(157833.16821861753)
# ic| restart: 62
#     valid(solution): np.True_
#     cost(solution): np.float64(178268.34191964692)
#     len(np.where(solution)[0]): 42
#     cost(best_solution): np.float64(157833.16821861753)
# ic| restart: 63
#     valid(solution): np.True_
#     cost(solution): np.float64(232625.7909765084)
#     len(np.where(solution)[0]): 54
#     cost(best_solution): np.float64(157833.16821861753)
# ic| restart: 64
#     valid(solution): np.True_
#     cost(solution): np.float64(226800.19614631037)
#     len(np.where(solution)[0]): 53
#     cost(best_solution): np.float64(157833.16821861753)
# ic| restart: 65
#     valid(solution): np.True_
#     cost(solution): np.float64(167201.83404484377)
#     len(np.where(solution)[0]): 39
#     cost(best_solution): np.float64(157833.16821861753)
# ic| restart: 66
#     valid(solution): np.True_
#     cost(solution): np.float64(167606.1779502348)
#     len(np.where(solution)[0]): 39
#     cost(best_solution): np.float64(157833.16821861753)
# ic| restart: 67
#     valid(solution): np.True_
#     cost(solution): np.float64(176044.41694548875)
#     len(np.where(solution)[0]): 41
#     cost(best_solution): np.float64(157833.16821861753)
# ic| restart: 68
#     valid(solution): np.True_
#     cost(solution): np.float64(200581.20394208448)
#     len(np.where(solution)[0]): 47
#     cost(best_solution): np.float64(157833.16821861753)
# ic| restart: 69
#     valid(solution): np.True_
#     cost(solution): np.float64(187689.37875554178)
#     len(np.where(solution)[0]): 44
#     cost(best_solution): np.float64(157833.16821861753)
# ic| restart: 70
#     valid(solution): np.True_
#     cost(solution): np.float64(170931.92714520666)
#     len(np.where(solution)[0]): 40
#     cost(best_solution): np.float64(157833.16821861753)
# ic| restart: 71
#     valid(solution): np.True_
#     cost(solution): np.float64(218415.36600813534)
#     len(np.where(solution)[0]): 51
#     cost(best_solution): np.float64(157833.16821861753)
# ic| restart: 72
#     valid(solution): np.True_
#     cost(solution): np.float64(175300.86183430263)
#     len(np.where(solution)[0]): 41
#     cost(best_solution): np.float64(157833.16821861753)
# ic| restart: 73
#     valid(solution): np.True_
#     cost(solution): np.float64(175778.23960462594)
#     len(np.where(solution)[0]): 41
#     cost(best_solution): np.float64(157833.16821861753)
# ic| restart: 74
#     valid(solution): np.True_
#     cost(solution): np.float64(183206.53538711695)
#     len(np.where(solution)[0]): 43
#     cost(best_solution): np.float64(157833.16821861753)
# ic| restart: 75
#     valid(solution): np.True_
#     cost(solution): np.float64(181282.33367422505)
#     len(np.where(solution)[0]): 42
#     cost(best_solution): np.float64(157833.16821861753)
# ic| restart: 76
#     valid(solution): np.True_
#     cost(solution): np.float64(162738.2248227666)
#     len(np.where(solution)[0]): 38
#     cost(best_solution): np.float64(157833.16821861753)
# ic| restart: 77
#     valid(solution): np.True_
#     cost(solution): np.float64(165959.9006581423)
#     len(np.where(solution)[0]): 39
#     cost(best_solution): np.float64(157833.16821861753)
# ic| restart: 78
#     valid(solution): np.True_
#     cost(solution): np.float64(184016.8683781947)
#     len(np.where(solution)[0]): 43
#     cost(best_solution): np.float64(157833.16821861753)
# ic| restart: 79
#     valid(solution): np.True_
#     cost(solution): np.float64(184022.28184185116)
#     len(np.where(solution)[0]): 43
#     cost(best_solution): np.float64(157833.16821861753)
# ic| restart: 80
#     valid(solution): np.True_
#     cost(solution): np.float64(213694.2795868371)
#     len(np.where(solution)[0]): 50
#     cost(best_solution): np.float64(157833.16821861753)
# ic| restart: 81
#     valid(solution): np.True_
#     cost(solution): np.float64(183920.50512112593)
#     len(np.where(solution)[0]): 43
#     cost(best_solution): np.float64(157833.16821861753)
# ic| restart: 82
#     valid(solution): np.True_
#     cost(solution): np.float64(185224.1015997364)
#     len(np.where(solution)[0]): 43
#     cost(best_solution): np.float64(157833.16821861753)
# ic| restart: 83
#     valid(solution): np.True_
#     cost(solution): np.float64(217782.29274262534)
#     len(np.where(solution)[0]): 51
#     cost(best_solution): np.float64(157833.16821861753)
# ic| restart: 84
#     valid(solution): np.True_
#     cost(solution): np.float64(197621.29489961237)
#     len(np.where(solution)[0]): 46
#     cost(best_solution): np.float64(157833.16821861753)
# ic| restart: 85
#     valid(solution): np.True_
#     cost(solution): np.float64(196672.09040169857)
#     len(np.where(solution)[0]): 46
#     cost(best_solution): np.float64(157833.16821861753)
# ic| restart: 86
#     valid(solution): np.True_
#     cost(solution): np.float64(187297.7324729357)
#     len(np.where(solution)[0]): 44
#     cost(best_solution): np.float64(157833.16821861753)
# ic| restart: 87
#     valid(solution): np.True_
#     cost(solution): np.float64(230874.522043267)
#     len(np.where(solution)[0]): 54
#     cost(best_solution): np.float64(157833.16821861753)
# ic| restart: 88
#     valid(solution): np.True_
#     cost(solution): np.float64(189228.65059814416)
#     len(np.where(solution)[0]): 44
#     cost(best_solution): np.float64(157833.16821861753)
# ic| restart: 89
#     valid(solution): np.True_
#     cost(solution): np.float64(188993.04295491352)
#     len(np.where(solution)[0]): 44
#     cost(best_solution): np.float64(157833.16821861753)
# ic| restart: 90
#     valid(solution): np.True_
#     cost(solution): np.float64(239677.96467489417)
#     len(np.where(solution)[0]): 56
#     cost(best_solution): np.float64(157833.16821861753)
# ic| restart: 91
#     valid(solution): np.True_
#     cost(solution): np.float64(222629.9293974993)
#     len(np.where(solution)[0]): 52
#     cost(best_solution): np.float64(157833.16821861753)
# ic| restart: 92
#     valid(solution): np.True_
#     cost(solution): np.float64(205255.96924379433)
#     len(np.where(solution)[0]): 48
#     cost(best_solution): np.float64(157833.16821861753)
# ic| restart: 93
#     valid(solution): np.True_
#     cost(solution): np.float64(162957.3885211892)
#     len(np.where(solution)[0]): 38
#     cost(best_solution): np.float64(157833.16821861753)
# ic| restart: 94
#     valid(solution): np.True_
#     cost(solution): np.float64(184643.78676847753)
#     len(np.where(solution)[0]): 43
#     cost(best_solution): np.float64(157833.16821861753)
# ic| restart: 95
#     valid(solution): np.True_
#     cost(solution): np.float64(159359.29277272345)
#     len(np.where(solution)[0]): 37
#     cost(best_solution): np.float64(157833.16821861753)
# ic| restart: 96
#     valid(solution): np.True_
#     cost(solution): np.float64(195718.1100091436)
#     len(np.where(solution)[0]): 46
#     cost(best_solution): np.float64(157833.16821861753)
# ic| restart: 97
#     valid(solution): np.True_
#     cost(solution): np.float64(179339.10349742338)
#     len(np.where(solution)[0]): 42
#     cost(best_solution): np.float64(157833.16821861753)
# ic| restart: 98
#     valid(solution): np.True_
#     cost(solution): np.float64(176053.30509321622)
#     len(np.where(solution)[0]): 41
#     cost(best_solution): np.float64(157833.16821861753)
# ic| restart: 99
#     valid(solution): np.True_
#     cost(solution): np.float64(228039.5241186496)
#     len(np.where(solution)[0]): 53
#     cost(best_solution): np.float64(157833.16821861753)
# Best solution found with tweak and restart: 157833.16821861753
